# %% [markdown]
# <a href="https://colab.research.google.com/github/shishir-py/Classification-using-Deep-learning/blob/main/image_captioning_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

from PIL import Image

# %%
seed = 111
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
IMAGE_SIZE = (299, 299)
VOCAB_SIZE = 10000
seq_length = 25
EMBED_DIM = 512
FF_DIM = 512
BATCH_SIZE = 64
EPOCHS = 30
AUTOTUNE = tf.data.AUTOTUNE
seed = 42
tf.random.set_seed(seed)
image_size = (500, 375)  # The target image size

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf

captions_file="/content/drive/MyDrive/Laptop/Image captioning project/archive/Copy of translated_nepali_captions.txt"
images_folder="/content/drive/MyDrive/Laptop/Image captioning project/archive/Images"

# %%
import os
import numpy as np

def load_captions_data(filename, seq_length=20):

    caption_mapping = {}
    text_data = []

    with open(filename, "r", encoding="utf-8") as caption_file:
        caption_lines = caption_file.readlines()

    for line in caption_lines:
        line = line.rstrip("\n")
        # Image name and captions are separated using a tab
        img_name, caption = line.split("#", maxsplit=1)

        # Each image is repeated five times for the five different captions.
        # Each image name has a suffix `#(caption_number)`
        img_name = img_name.split("#")[0]
        img_name = os.path.join(images_folder, img_name.strip())

        # We will remove captions that are either too short or too long
        tokens = caption.strip().split()

        if len(tokens) < 5 or len(tokens) > seq_length:
            continue

        if img_name.endswith(".jpg"):
            # We will add a start and an end token to each caption
            caption = "<start> " + caption.strip() + " <end>"
            text_data.append(caption)

            if img_name in caption_mapping:
                caption_mapping[img_name].append(caption)
            else:
                caption_mapping[img_name] = [caption]

    return caption_mapping, text_data


def train_val_split(caption_data, train_size=0.8, shuffle=True):

    all_images = list(caption_data.keys())

    if shuffle:
        np.random.shuffle(all_images)

    train_size = int(len(caption_data) * train_size)

    train_data = {img_name: caption_data[img_name] for img_name in all_images[:train_size]}
    valid_data = {img_name: caption_data[img_name] for img_name in all_images[train_size:]}

    return train_data, valid_data




# Load the dataset
caption_mapping, text_data = load_captions_data(captions_file)

# Split the dataset into training and validation sets
train_data, valid_data = train_val_split(caption_mapping)

# Print the number of samples in the training and validation sets
print("Number of training samples:", len(train_data))
print("Number of validation samples:", len(valid_data))
# Out:
# Number of training samples: 6472
# Number of validation samples: 1619

# %%
train_data
# Out:
# {'/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/1423126855_6cd2a3956c.jpg': ['<start> 0 हरियो मैदानमा भेडाहरू लिएर एक पदयात्री पोज। <end>',
#   '<start> 1 झोला बोकेको मानिस घाँसको ठूलो मैदानमा हिंड्दैछ। <end>',
#   '<start> 2 झोला लगाएको खेतमा एकजना मानिस र उसको पछाडि भेडा र पहाडहरू छन्। <end>',
#   '<start> 3 पैदल यात्राको झोला लगाएको मान्छे काठको पोलमा झुकेको छ <end>',
#   '<start> 4 कालो शर्ट लगाएको मान्छे घाँसे मैदानमा पोलको छेउमा उभिरहेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3606084228_6286a52875.jpg': ['<start> 0 एक साइकल यात्रीले आफ्नो बाइक हाम फालेको बेला पहाडको छेउमा फैलिएको भीडले हेरिरहेको छ। <end>',
#   '<start> 1 एक डर्ट बाइकरले प्रतिस्पर्धा गर्दा दर्शकहरूले हेर्छन्। <end>',
#   '<start> 2 सेतो ज्याकेट र हेलमेट लगाएको मानिसले आफ्नो बाइकमा चाल चलाउँछ। <end>',
#   '<start> 3 एक जना मानिसले फोहोर साइकलमा मिडएयर स्टन्ट प्रदर्शन गर्दैछ जबकि पृष्ठभूमिमा मानिसहरू हेरिरहेका छन्। <end>',
#   '<start> 4 माउन्टेन बाइक रेसरले आफ्नो बाइकलाई दर्शकले हेर्दा हाम फालेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3028561714_83fb921067.jpg': ['<start> 0 एउटा सेतो र खैरो कुकुर हावामा उफ्रिरहेको छ। <end>',
#   '<start> 1 एउटा सेतो र खैरो कुकुर मैदानमा दौडन्छ। <end>',
#   '<start> 2 एउटा सेतो कुकुर हावामा उफ्रन्छ। <end>',
#   '<start> 3 सेतो र खैरो कुकुर घाँसबाट छिट्टै दौडिरहेको छ। <end>',
#   '<start> 4 सेतो र खैरो कुकुर घाँसमा दौडन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2914737181_0c8e052da8.jpg': ['<start> 0 एकजना मानिसलाई पानीबाट तान्दै गर्दा कुनै चीजमा झुण्डिएको छ। <end>',
#   '<start> 1 एउटा मानिस छाल समात्नको लागि खुट्टामा बोर्ड लगाएर चकनाचूर समुद्रमा प्यारासेल गर्दैछ। <end>',
#   '<start> 2 तानेको बेला एउटा मानिस वाटरस्कीस गर्दैछ। <end>',
#   '<start> 4 मानिस नीलो समुद्रमा वाटरस्कीइङ गर्दै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3070485870_eab1a75c6f.jpg': ['<start> 0 एउटा स्नोबोर्डर केही रूखहरू नजिक उफ्रिएपछि हावामा छ। <end>',
#   '<start> 1 एक स्नोबोर्डर हिउँको ढलानमा उफ्रिरहेको छ। <end>',
#   '<start> 2 एक स्नोबोर्डरले जंगलको पृष्ठभूमिमा उफ्रन्छ। <end>',
#   '<start> 3 एक स्नोबोर्डरले हिउँमा जम्प गर्छ। <end>',
#   '<start> 4 स्नोबोर्डरले हिउँमा आफ्नो बोर्डमा स्टन्ट गर्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3150659152_2ace03690b.jpg': ['<start> 0 खजूरको रूखले घेरिएको खोलामा एउटा नीलो डुङ्गामा माछा मार्ने मानिस। <end>',
#   '<start> 1 नीलो क्यानोमा एक मानिस अग्लो हत्केलाको फ्रन्डहरू भएको सिमसार भूमिमा नेभिगेट गर्दै। <end>',
#   '<start> 2 एकजना मानिसले जङ्गलको पानीमा डुङ्गी ल्याएको छ। <end>',
#   '<start> 3 एउटा कारण केही बिरुवाहरूको अगाडि निलो क्यानोमा छ। <end>',
#   '<start> 4 ट्रपिकल बैंकको छेउमा एक्वा बोटमा व्यक्ति <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3174228611_6cf9d2266b.jpg': ['<start> 0 एक बास्केटबल खेलाडी रातो र सेतो जर्सी लगाएर कोर्टमा दौडिरहेको बेला। <end>',
#   '<start> 1 सेतो खेलकुद पोशाकमा कालो छाला भएको मानिस बास्केटबल खेल्छ। <end>',
#   '<start> 2 बास्केटबल खेलको क्रममा एक जना मानिसले बल ड्रिबल गर्दैछ। <end>',
#   '<start> 3 एक SMU बास्केटबल खेलाडी बास्केटबल खेल्दै। <end>',
#   '<start> 4 SMU बास्केटबल खेलाडी टोकरीमा जान्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2701271123_6761bc5f26.jpg': ['<start> 0 एउटा कालो कुकुरले माटोको मैदानमा रहेको फुटबल बलमा टोकेको छ। <end>',
#   '<start> 1 माटोमा हिंडिरहेको कालो कुकुरको मुखमा फुटबलको बल छ। <end>',
#   '<start> 2 एउटा सानो कुकुर मुखमा फुटबल बल लिएर माटोले ढाकिएको ठाउँमा हिंडिरहेको छ। <end>',
#   '<start> 3 मुखमा पुरानो फुटबल बल समातेको कालो कुकुर <end>',
#   '<start> 4 कालो कुकुर मुखमा फुटबलको बल लिएर माटोमा हिंडिरहेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3523819210_99782628fc.jpg': ['<start> 0 एउटा मान्छे दुईवटा कार्डबोर्ड क्यानभासको पछाडि बसेको छ। <end>',
#   '<start> 1 नीलो धातुको कुर्सीमा बसेको मान्छे। <end>',
#   '<start> 2 सडकमा एउटा बोर्डको छेउमा कुर्सीमा बसेको मान्छे। <end>',
#   '<start> 3 मानिस ठूला चित्रहरूको नजिक बाहिर निलो कुर्सीमा बसिरहेको छ। <end>',
#   '<start> 4 मान्छे काठको दुई टुक्राको छेउमा निलो कुर्सीमा बसिरहेको छ <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/94232465_a135df2711.jpg': ['<start> 0 एउटी महिला आइस स्केट गर्दै बच्चालाई बग्गीमा तान्दै। <end>',
#   '<start> 1 एउटी आमाले आफ्नी छोरीलाई हिउँको मैदानमा गाडीमा तान्दै। <end>',
#   '<start> 2 जमेको तालमा केटी लिएर गाडी तानेकी एक महिला <end>',
#   '<start> 3 केटीले बरफमा स्केटिङ गर्दा एउटा सानो बच्चालाई कार्टमा तान्छ। <end>',
#   '<start> 4 आइस स्केटिंग गरिरहेकी महिलाले कार्टमा सानी केटीलाई बरफ पार गरिरहेकी छिन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2183227136_8bb657846b.jpg': ['<start> 0 एक बच्चा सूर्यास्तको बेला समुद्र तटको बालुवामा खेल्दै। <end>',
#   '<start> 1 एक बच्चा क्षितिजमा सूर्य कम भएको समुद्र तटको बालुवामा खेल्दै। <end>',
#   '<start> 2 सूर्यास्तमा समुद्रको छेउमा समुद्र तटमा एक व्यक्ति। <end>',
#   '<start> 3 अग्रभूमिमा बच्चासँग समुद्र तटमा सूर्यास्तको छवि। <end>',
#   '<start> 4 कसैले सूर्यास्तको बेला एउटा स्थिर तालमा एउटा सानो डुङ्गा चलाउँछ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3613242966_a1c63a0174.jpg': ['<start> 0 एउटा कुकुर पानीमा खेल्छ। <end>',
#   '<start> 2 एउटा कुकुर पानीमा पौडी खेल्छ। <end>',
#   '<start> 3 एउटा ट्यान कुकुर पानीमा पौडी खेल्ने क्रममा छर्किन्छ। <end>',
#   '<start> 4 कुकुरले कुनै न कुनै रूपमा पानीमा छाल निम्त्याउँछ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2895700779_fac1d9d278.jpg': ['<start> 0 छोटो रातो कपाल भएको महिलाको क्लोजअप। <end>',
#   '<start> 1 नियोन रातो कपाल र भौंहरू भएको केटी। <end>',
#   '<start> 2 रातो कपाल र रातो भौं भएकी केटी बीच-बीचमा देखिन्छ। <end>',
#   '<start> 3 चम्किलो रातो कपाल र रातो भौं भएकी महिला बाहिर कसैसँग कुरा गर्दै। <end>',
#   '<start> 4 केटीको रातो कपाल र भौहें, कानमा धेरै छेड्ने र पीठमा ट्याटु छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3006926228_cf3c067b3e.jpg': ['<start> 0 एक व्यक्तिले आफ्नो हात हावामा उठाइरहेको छ र यसमा संयुक्त राज्य अमेरिका लेखिएको टी-सर्ट छ। <end>',
#   '<start> 1 एक जना मानिस रातमा भीडको बीचमा उत्सव मनाउने इशाराहरू गर्दछ। <end>',
#   '<start> 2 पुरुष र महिला हर्षोल्लास गर्दै <end>',
#   '<start> 3 मानिसहरू रातमा आफ्नो हात फैलाएर कराउँछन्। <end>',
#   '<start> 4 पुरुष र एक महिलाले आफ्नो हात उठाएका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2855594918_1d1e6a6061.jpg': ['<start> 0 एक बाइकर, सबै माटोले ढाकेको, नीलो बाइक चलाउँदै। <end>',
#   '<start> 1 हिलो सुन्तला रंगको शर्टमा बाइकर निलो रेसिङ बाइकमा सवार <end>',
#   '<start> 2 सेतो हेलमेट लगाएको सुन्तला रंगको शर्ट लगाएको एक जना मानिस बाइक चलाउँदै छन्। <end>',
#   '<start> 3 सुन्तला रंगको शर्ट र कालो र सेतो हेलमेट लगाएको साइकलमा सवार व्यक्ति <end>',
#   '<start> 4 मोटरसाइकलमा सवार मानिसले भर्खरै हिलोमा हिड्दै सिध्यायो। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3223709894_97824ba76f.jpg': ['<start> 0 एउटा खैरो कुकुर एउटा कान उठाएर घाँसमा दौडन्छ। <end>',
#   '<start> 1 फ्लफी कुकुर घाँसमा दौडन्छ। <end>',
#   '<start> 2 एउटा घाँसे क्षेत्र बाट दौडिरहेको कुकुर। <end>',
#   '<start> 3 घाँसेको आँगनबाट गुडिरहेको एउटा सानो खैरो पोखरी। <end>',
#   '<start> 4 एउटा सानो कुकुर घाँसमा दौडन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/469021173_aa31c07108.jpg': ['<start> 0 सुन्तला रंगको झोला लगाएको एक पदयात्री लामो घाँसमा हिंड्दैछ। <end>',
#   '<start> 1 एउटा ठूलो सुन्तला रंगको झोला लिएर ब्रस लगाएर हिँडिरहेको मान्छे। <end>',
#   '<start> 2 जंगली क्षेत्रमा सुन्तलाको झोला बोकेको मान्छे। <end>',
#   '<start> 3 ठूलो झोला लिएर अग्लो घाँस हुँदै पैदल यात्रा गर्दै एक व्यक्ति। <end>',
#   '<start> 4 कालो र सुन्तला रंगको झोला बोकेको पदयात्री जंगली क्षेत्रमा हिंड्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2066271441_1f1f056c01.jpg': ['<start> 0 रंगीन बल बोकेको कालो कुकुर पौडी खेल्छ। <end>',
#   '<start> 1 एउटा कालो कुकुरले पानीमा बल निकाल्दै छ। <end>',
#   '<start> 2 एउटा कालो कुकुर मुखमा बल लिएर पौडी खेलिरहेको छ। <end>',
#   '<start> 3 कालो कुकुर मुखमा रंगीन बल लिएर पानीमा पौडी खेल्छ। <end>',
#   '<start> 4 कालो कुकुरले मुखमा चम्किलो बल लिएर पानीमा प्याडल गर्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2866254827_9a8f592017.jpg': ['<start> 0 मोटरसाइकलमा सवार एक व्यक्ति आफ्नो पछाडिको टायरमा सवार थिए। <end>',
#   '<start> 1 पहेँलो खेलकुद बाइकमा सवार एकजना मानिसले कालो बाइकमा सवार उसको साथीले समात्दा चक्का चलाउँछ। <end>',
#   '<start> 2 एक पहेँलो मोटरसाइकल चालकले व्हीली पप गर्दैछ। <end>',
#   '<start> 3 सुन्तला राइडर एक पाङ्ग्रामा मोटरसाइकल चलाउँदै हुनुहुन्छ। <end>',
#   '<start> 4 धमिलो सडकमा दुई मोटरसाइकल चालक, एक सवार ह्वीलिङ गर्दै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3254817653_632e840423.jpg': ['<start> 1 वयस्कहरूको समूह स्वेटर लगाउँछन् र आफ्नो हात आफ्नो खल्तीमा राख्छन्। <end>',
#   '<start> 2 पाँच वयस्कहरूको समूह भवनको अगाडि पोज दिँदै उभिएको छ। <end>',
#   '<start> 3 मानिसहरूको समूह सँगै उभिएर घरको अगाडि पोज दिँदै। <end>',
#   '<start> 4 इट्टाको भवन अगाडि चार केटा र एउटी केटीको समूहले गोली हान्यो। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2926786902_815a99a154.jpg': ['<start> 0 पहेँलो ज्याकेटमा स्कीयर पहाडहरू माथि हावामा उडेको हुन्छ। <end>',
#   '<start> 1 एक स्कीयर पहाडहरूको दृश्यको साथ हावामा उचालिन्छ। <end>',
#   '<start> 2 फ्लोरोसेन्ट ज्याकेट लगाएर स्कीइङ गर्ने मानिस एकदमै माथि उफ्रन्छ र उ उडिरहेको जस्तो देखिन्छ। <end>',
#   '<start> 3 सोमोन हावामा स्की जम्प गर्दै उच्च छ। <end>',
#   '<start> 4 हरियो ज्याकेट र सेतो प्यान्ट लगाएको स्कीयर लगभग आकाशमा उडेको देखिन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2339106348_2df90aa6a9.jpg': ['<start> 0 कालो खैरो कपाल र नीलो स्कार्फमा आँखा भएको केटी फरको कोट लगाएकी केटीको छेउमा उभिरहेकी छिन्। <end>',
#   '<start> 1 एक एसियाली केटा र एक एसियाली केटी मानिसहरूको भीडमा मुस्कुराउँदै छन्। <end>',
#   '<start> 3 दुईवटा कालो कपाल भएका केटीहरू भीडमा छन्। <end>',
#   '<start> 4 भीडमा उभिएर दुई केटीहरू एकअर्कालाई फरक दिशामा हेरिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3514297698_0512623955.jpg': ['<start> 0 कालो र खैरो कुकुर समुद्र तटमा टेनिस बल समात्छ <end>',
#   '<start> 1 एउटा कुकुरले समुद्र तटमा पहेँलो टेनिस बल समातिरहेको छ। <end>',
#   '<start> 2 एउटा कुकुर समुद्र नजिक टेनिस बलको लागि हाम फाल्दै <end>',
#   '<start> 3 एउटा कुकुर सर्फमा बल समात्न उफ्रन्छ। <end>',
#   '<start> 4 एउटा दाग भएको कुकुर समुद्र तटमा बल समाउन आफ्नो पछाडिको खुट्टामा उभिएको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2500354186_0836309cc9.jpg': ['<start> 0 एउटा केटा साइकलको टायर काँधमा लिएर धुलोले भरिएको चट्टानी आँगनबाट हिंडिरहेको छ। <end>',
#   '<start> 1 एउटा सानो बच्चाले ठूलो हुप बोकेको छ। <end>',
#   '<start> 2 एउटा सानो बच्चाले आफ्नो काँधमा टायर समातेको छ। <end>',
#   '<start> 3 एउटा सानो केटाले काँधमा साइकलको टायर बोकेको छ। <end>',
#   '<start> 4 एउटा जवान केटा फोहोर सडकमा टायर रबर बोकेर हिँडिरहेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/1969573381_5ecfae4c80.jpg': ['<start> 0 रूखहरूले घेरिएको खैरो र सेतो जनावर। <end>',
#   '<start> 1 बाहिर उभिएको एउटा कुकुरले क्यामेरा हेरिरहेको छ। <end>',
#   '<start> 2 हरियो बिरुवाको छेउमा उभिएको ट्यान र सेतो कुकुर। <end>',
#   '<start> 3 एउटा ट्यान कुकुर केही बिरुवाको अगाडि उभिएको छ। <end>',
#   '<start> 4 डिंगो जस्तो देखिने खैरो कुकुर जंगलबाट बाहिर देखिन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3639105305_bd9cb2d1db.jpg': ['<start> 0 आमा र छोरी झरनाको अगाडि पोज दिँदै। <end>',
#   '<start> 1 एक महिला र बच्चा पृष्ठभूमिमा झरनाको साथ लग र ढुङ्गाको बारमा बसिरहेका छन्। <end>',
#   '<start> 2 एउटी महिला र केटी झरनाको अगाडि बारमा बसिरहेका <end>',
#   '<start> 3 झरनाको अगाडि एउटी महिला र उनको छोरी <end>',
#   '<start> 4 एउटी महिला झरनाको अगाडि बारमा केटीसँग बसिरहेकी छिन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2046778775_0dd7cac6ab.jpg': ['<start> 0 बच्चाहरूको एउटा समूह स्टेजमा प्रदर्शनको लागि लाइनमा छन्। <end>',
#   '<start> 1 केटीहरू र केटाहरूको समूह स्कूलको स्टेजमा सँगै अभ्यास गर्छन् जबकि केही वयस्क र बच्चाहरू हेर्छन्। <end>',
#   '<start> 2 बच्चाहरूको एउटा समूह प्रदर्शन गर्न तयार दर्शकहरूको अगाडि स्टेजमा उभिरहेको छ। <end>',
#   '<start> 4 बच्चाहरूको ठूलो समूह दर्शकहरूको अगाडि स्टेजमा प्रदर्शन गर्दै <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2973272684_4d63cbc241.jpg': ['<start> 0 सुनको हेलमेट लगाएको फुटबल खेलाडी फुटबल लिएर दौडिरहेको छ। <end>',
#   '<start> 1 बैजनी जर्सी लगाएका एक फुटबल खेलाडी टचडाउनको लागि बल दौडिरहेका छन्। <end>',
#   '<start> 2 रेफ्रीले आफ्नो सिट्टी बजाउदा एक फुटबल खेलाडी मैदानभरि दौडन्छ। <end>',
#   '<start> 3 एक फुटबल खेलाडी फुटबल बोकेर अफिसियलको छेउबाट दौडन्छ। <end>',
#   '<start> 4 फुटबल खेलाडीले बललाई रेफ्रीको छेउबाट दौडन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/1505686764_9e3bcd854a.jpg': ['<start> 0 रातो चड्डी लगाएको एक मानिस नदीको छेउमा लट्ठी बोकेर हिंडिरहेको छ। <end>',
#   '<start> 1 रातो चड्डी लगाएको मानिस नदीको छेउमा चट्टानमा उभिएको <end>',
#   '<start> 2 एकजना मानिस चट्टानमा हिंडिरहेको छ जसको वरिपरि पानी बगिरहेको छ। <end>',
#   '<start> 3 खोलाको छेउमा उभिएको शर्टलेस मानिस। <end>',
#   '<start> 4 पदयात्री एउटा खाडीको नजिक पुग्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3205839744_24504ba179.jpg': ['<start> 0 हरियो कुसनमा सुतिरहेको खैरो कुकुर। <end>',
#   '<start> 1 खैरो कुकुर हरियो कुसनमा आराम गर्छ। <end>',
#   '<start> 2 एउटा खैरो कुकुर हरियो सिरानीमा सुतिरहेको छ। <end>',
#   '<start> 3 हरियो कुसनमा सुतिरहेको कुकुर। <end>',
#   '<start> 4 एउटा ठूलो खैरो कुकुर ठूलो, हरियो कुकुरको ओछ्यानमा घाममा सुतेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2596474836_79468f23a0.jpg': ['<start> 0 एउटी महिला एक बच्चालाई पोखरीमा पौडी खेल्न मद्दत गर्दै। <end>',
#   '<start> 1 सेतो पौडी टोपी लगाएकी एउटी महिलाले एउटा बच्चालाई पौंडी पोखरीमा कसरी पौडी खेल्ने भनेर सिकाउँछिन्। <end>',
#   '<start> 2 एउटी महिलाले एउटा केटालाई स्विमिङ पुलमा समातिरहेकी छिन्। <end>',
#   '<start> 3 सेतो पौडी लगाएकी एउटी महिलाले एउटा सानो केटालाई पौंडी पोखरीमा समातिन्। <end>',
#   '<start> 4 केटालाई पौडी खेल्न सिकाउँदै महिला। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2045562030_654ddea5e5.jpg': ['<start> 0 किशोरहरूको समूह, एक गुलाबी कपाल भएको। <end>',
#   '<start> 1 किशोरहरूको एउटा समूह सिमेन्टको पर्खाल नजिक कुरा गर्दैछ। <end>',
#   '<start> 2 बालुवा स्तम्भहरू भएको भवनको छेउमा किशोरहरूको समूह कुरा गर्दै। <end>',
#   '<start> 3 गुलाबी स्ट्रेक कपाल भएका दुई केटीहरू र कालो कपाल भएका दुई केटाहरू कंक्रीट भवनको छेउमा उभिरहेका छन्। <end>',
#   '<start> 4 रङ्गिएको कपाल भएका दुई जवान केटीहरू कालो रंगका दुई केटाहरूसँग कुरा गर्दै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3550763985_800cfee7e4.jpg': ['<start> 0 बेसबल टोपी लगाएको मान्छेले आधा पाइपमा स्केटबोर्ड जम्प गर्छ। <end>',
#   '<start> 1 एक स्केटबोर्डरले र्\u200dयाम्पमा ट्रिक गर्छ। <end>',
#   '<start> 2 हिउँ परेको दिनमा जम्पको शीर्षमा कालो र सेतो टोपी लगाएको स्केटबोर्डर। <end>',
#   '<start> 3 कालो र सेतो टोपी लगाएको स्केटबोर्डर स्केट पार्कमा ओली प्रदर्शन गर्दै। <end>',
#   '<start> 4 स्केटबोर्डरले आधा पाइपको छेउमा ट्रिक गरिरहेको छ <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2544182005_3aa1332bf9.jpg': ['<start> 0 नीलो शर्ट लगाएको एउटा सानो केटा हेलमेट लगाएर दुई पाङ्ग्रे बाइक चलाउँदै छ। <end>',
#   '<start> 1 एक जवान केटा बैजनी रंगको साइकल चलाइरहेको छ। <end>',
#   '<start> 2 एउटा सानो बच्चा बैजनी रंगको साइकल चलाउँदै छ। <end>',
#   '<start> 3 रातो हेलमेट लगाएर एउटा सानो बच्चा बैजनी रंगको सानो साइकल चलाइरहेको छ। <end>',
#   '<start> 4 मोटरसाइकलको हेलमेट लगाएको एउटा सानो बच्चा दुई पाङ्ग्रे बाइक चलाउँछ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2565350330_c7f305e7f7.jpg': ['<start> 0 एउटा दाह्री भएको मानिस एउटा ठूलो रूखमुनि आफ्नो ढाडमा राखेको। <end>',
#   '<start> 1 खैरो दाह्री भएको मानिस रूखमुनि सुतिरहेको छ। <end>',
#   '<start> 2 रुखमुनि घाँसमा सुतिरहेको मान्छे। <end>',
#   '<start> 3 एउटा राम्रो लुगा लगाएको मान्छे लाठी र दाह्री लगाएको, पार्कको रूखमुनि सुतिरहेको। <end>',
#   '<start> 4 एक सेतो कपाल भएको मानिस आफ्नो छडी र टोपी तल राखेर रूखको छेउमा सुतेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3154693053_cfcd05c226.jpg': ['<start> 1 बास्केटबल खेलाडीले बललाई ड्रिबल गर्छ। <end>',
#   '<start> 2 एक मियामी बास्केटबल खेलाडीले बल ड्रिबल गर्छ र गम्भीर देखिन्छ। <end>',
#   '<start> 3 मियामी हरिकेन्स बास्केटबल खेलाडीसँग बलको कब्जा छ। <end>',
#   '<start> 4 सेतो स्ट्रिपमा बास्केटबल खेलाडी कोर्टमा बल ड्रिबल गर्दै छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2842032768_9d9ce04385.jpg': ['<start> 0 कालो कुखुराले रातो चपाउने खेलौना बोकेको बेला खैरो पोडलसँग खेल्दै। <end>',
#   '<start> 1 मुखमा खेलौना भएको कालो पोडल <end>',
#   '<start> 2 एउटा खेलौना भएको कालो कुकुर र एउटा पहेँलो कुकुर। <end>',
#   '<start> 3 यी दुई पोडलहरू, एउटा कालो र एउटा खैरो, खेलिरहेका छन्। <end>',
#   '<start> 4 रातो खेलौनासँग खेल्दै दुईवटा पोडल। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3242088278_43eea5d17e.jpg': ['<start> 0 पानीको पोखरी नजिक एउटा बाल्ड चील। <end>',
#   '<start> 1 एउटा बाल्ड चील खाडीको किनारमा बसेको छ। <end>',
#   '<start> 2 एउटा बाल्ड चील कम पानीमा उभिएको छ। <end>',
#   '<start> 4 चरा चट्टानको नजिक पानीमा हिंड्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3104400277_1524e4f758.jpg': ['<start> 1 फोहोर सडकमा चारवटा फोहोर बाइक सवार छन्। <end>',
#   '<start> 2 दुई साइकल यात्रीहरू लामो सवारी मार्गको सामना गरिरहेका छन्। <end>',
#   '<start> 3 दुई मोटोक्रस राइडरहरू रेसट्र्याकको काँधमा बस्छन्। <end>',
#   '<start> 4 मोटरसाइकलमा दुई जना मान्छे। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/1002674143_1b742ab4b8.jpg': ['<start> 0 रंगले ढाकेकी एउटी सानी केटी कचौरामा हात लिएर रंगिएको इन्द्रेणीको अगाडि बसिरहेकी छिन्। <end>',
#   '<start> 1 एउटी सानी केटी एउटा ठूलो चित्रित इन्द्रेणीको अगाडि बसिरहेकी छिन्। <end>',
#   '<start> 2 घाँसमा एउटी सानी केटी इन्द्रेणी भएको सेतो क्यानभासको अगाडि औंलाको पेन्टसँग खेल्छिन्। <end>',
#   '<start> 3 त्यहाँ इंद्रधनुष चित्रकारीको अगाडि सुँगुर बोकेकी एउटी केटी बसेकी छिन्। <end>',
#   '<start> 4 बाहिर घाँसमा पेन्टिङ गर्दै पिगटेलसहित युवती। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/219070971_ae43410b9e.jpg': ['<start> 0 एक फोहोर बाइकरले आफ्नो मोटरसाइकललाई चट्टान माथि धकेल्छ जबकि अर्को सवार हेर्छ। <end>',
#   '<start> 1 रातो पहिरनमा माटोको बाइकमा सवार एउटा मानिस चट्टानमाथि लडिरहेको छ भने अर्को मानिस रातो घडी हेर्दैछ। <end>',
#   '<start> 2 रातो पहिरनमा एकजना मानिसले आफ्नो मोटोक्रस बाइकलाई चट्टानमाथि धकेल्छ। <end>',
#   '<start> 3 एक जना मानिसले अर्को मानिसले आफ्नो फोहोर बाइक लिएर एउटा सानो ढुङ्गा चढ्न खोजेको हेरिरहेको छ। <end>',
#   '<start> 4 रातो पहिरन लगाएको मानिस चट्टानी जमिनबाट बाइक चलाउँदै गर्दा अर्को मानिसले हेर्दै <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2458269558_277012780d.jpg': ['<start> 0 सेतो र सुन्तला रंगको टी-सर्ट लगाएको एउटा गोरो केटा झोलामा खेलिरहेको छ। <end>',
#   '<start> 1 सर्फिङ सर्ट लगाएको केटा झुल्केमा झुलिरहेको छ। <end>',
#   '<start> 2 एउटा बच्चा झुल्दै गर्दा मुस्कुराउँदै छ। <end>',
#   '<start> 3 एउटा सानो केटा खेल मैदानमा झुल्दै। <end>',
#   '<start> 4 साना बच्चा झुल्दै झुल्दै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2448793019_5881c025f9.jpg': ['<start> 0 जंगली कपाल र सनग्लास लगाएको बच्चा नीलो स्लाइडबाट बाहिर निस्किरहेको छ। <end>',
#   '<start> 1 स्लाइडको फेदमा रहेको एउटा सानो बच्चाको कपाल टाँसिएको छ। <end>',
#   '<start> 2 नीलो जिन्स लगाएको एउटा सानो बच्चा नीलो स्लाइड तल सर्दै <end>',
#   '<start> 3 सनग्लास लगाएको सानो बच्चा निलो स्लाइडको आधारमा छ। <end>',
#   '<start> 4 स्लाइडको फेदमा बच्चाको विकृत फोटो। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2744690159_fe2c89e55b.jpg': ['<start> 0 चार कुकुरहरू पानीमा छर्किरहेका छन् <end>',
#   '<start> 1 तीनवटा खैरो र कालो कुकुरहरू पानीमा छर्किरहेका छन्। <end>',
#   '<start> 2 तीनवटा खैरो कुकुरहरू पानीमा छन्। <end>',
#   '<start> 3 तीनवटा खैरो कुकुर समुद्रमा खेलिरहेका छन्। <end>',
#   '<start> 4 तीनवटा कुकुर पानीमा खेलिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/282131366_5f9a39c43c.jpg': ['<start> 0 एउटी महिला सूर्य प्रतिबिम्बित चट्टानी किनारा भएको ताल नजिकै दर्शकहरूसँग टाइट्रोप हिंड्ने प्रयास गरिरहेकी छिन्। <end>',
#   '<start> 1 एउटी महिला सूर्यास्त हुने बेलामा डोरीमा हिंडिरहेकी छिन्। <end>',
#   '<start> 2 सूर्यास्त हुँदा दायाँतिर झुकेकी महिला। <end>',
#   '<start> 3 केटी पृष्ठभूमिमा एक पुरुषसँग सूर्यास्तमा सन्तुलित हुन्छिन् <end>',
#   '<start> 4 महिला साँझमा तालको किनारमा नाच्दै छिन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2613993276_3c365cca12.jpg': ['<start> 0 घाँसे मैदानमा एउटा कुकुर मुखमा बल लिएर दौडन्छ। <end>',
#   '<start> 1 मुखमा बल लिएर मैदानभरि दौडिरहेको कुकुर। <end>',
#   '<start> 2 मैदानमा दौडिरहेको बल भएको कुकुर। <end>',
#   '<start> 3 एउटा सानो कुकुरले खुला घाँस मैदानमा बल ल्याइरहेको छ। <end>',
#   '<start> 4 लामो कपाल भएको कुकुर मुखमा पहेंलो बल लिएर ल्यानमा दौडन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2836325261_a3bf5c59be.jpg': ['<start> 0 रातो लुगा लगाएकी एउटी महिला ब्यागपाइप खेलिरहेकी छिन्। <end>',
#   '<start> 1 रातो लुगा लगाएकी एक महिला वाद्य बजाउँदै। <end>',
#   '<start> 2 रातो मध्ययुगीन प्रकारको लुगा लगाएकी एक महिला ब्यागपाइप वा यस्तै प्रकारको उपकरण बजाउँदै। <end>',
#   '<start> 3 पोशाक लगाएकी एउटी महिला ब्यागपाइप खेलिरहेकी छिन्। <end>',
#   '<start> 4 रातो पोशाक लगाएकी एउटी महिलाले इट्टाको पर्खालमा वाद्य बजाउँदै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2603125422_659391f961.jpg': ['<start> 0 भित्तिचित्र भरिएको सडकमा एउटा कार पार्क गरिएको छ। <end>',
#   '<start> 1 भित्तिचित्र बिग्रेको पर्खालले कारको छेउमा केही मानिसहरू भेला हुने काम गर्दछ। <end>',
#   '<start> 2 चारजना मानिसहरू भित्तामा झुन्डिएका छन्। <end>',
#   '<start> 3 केही वयस्कहरू रातमा कला भित्तिचित्रले ढाकिएको पर्खालमा उभिन्छन्। <end>',
#   '<start> 4 भित्ताको भित्ता अगाडि दुईजना मानिस सडकको मान्छेसँग कुरा गर्दै <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/248174959_2522871152.jpg': ['<start> 0 रातो टी-शर्ट लगाएकी एउटी केटी बादलको माथि चट्टानमा बसिरहेकी छिन्। <end>',
#   '<start> 1 एउटा केटी एउटा ठूलो पहाडको छेउमा एउटा खुट्टा झुन्ड्याएर बसिरहेकी छिन्। <end>',
#   '<start> 2 रातो शर्ट लगाएकी एउटी महिला चट्टानको छेउमा बसिरहेकी छिन्। <end>',
#   '<start> 3 रातो पहिरनमा एउटी महिला ठाडो चट्टानको छेउमा बसिरहेकी छिन्। <end>',
#   '<start> 4 रातो शर्ट लगाएकी एउटी महिला अग्लो चट्टानको छेउमा बसिरहेकी छिन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/1932314876_9cc46fd054.jpg': ['<start> 0 नीलो टप लगाएकी केटीको खुट्टा धारामा छ। <end>',
#   '<start> 1 एक पदयात्रीले खैरो जुत्ता लगाएर आफ्नो खुट्टा खोलामा हाल्छ। <end>',
#   '<start> 2 नीलो शर्ट र सर्ट लगाएका एक जना मानिस ढुङ्गाको खोलामा खुट्टा भिजाएर चट्टानमा आराम गरिरहेका छन्। <end>',
#   '<start> 3 एक व्यक्ति धाराको ओछ्यानमा चिल्लो ढुङ्गाको छेउमा बसिरहेको छ। <end>',
#   '<start> 4 नीलो शर्ट, प्लेड शर्ट र खैरो जुत्ता लगाएकी एउटी महिला, तौलियामा बसेर चट्टानी खाडीमा आफ्नो खुट्टा भिजाउँदै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3725814794_30db172f67.jpg': ['<start> 0 मार्शल आर्ट प्रदर्शन गर्ने एक व्यक्तिले आफ्नो प्रतिद्वन्द्वीलाई लात हानेको छ। <end>',
#   '<start> 1 मार्शल आर्ट म्याचको क्रममा, एक व्यक्तिले अर्कोलाई अनुहारमा लात हान्न खोज्छ। <end>',
#   '<start> 2 दुई पुरुष कराते प्रतियोगितामा प्रतिस्पर्धा गर्छन्। <end>',
#   '<start> 3 कराते लुगा लगाएका दुई जना मानिस झगडा गरिरहेका छन्। <end>',
#   '<start> 4 कालो बेल्ट लगाएका सेतो लगाएका दुई जना कराते खेल्दै छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/61209225_8512e1dad5.jpg': ['<start> 0 तोपहरू फायर गर्ने तोप टोलीहरूसँग गृहयुद्धको पुन: प्रवर्तन। <end>',
#   '<start> 1 पुरानो फेसनको तोप चलाउने पुरुषहरूको समूह। <end>',
#   '<start> 3 सिभिल युद्धको पुनरावृत्तिमा भाग लिने धेरै पुरुषहरू <end>',
#   '<start> 4 युद्धका पुनराज्ञहरूले तोप चलाउँछन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3517023411_a8fbd15230.jpg': ['<start> 0 एक बाइकर दौडिरहेको छ र धावकहरूसँग रहन <end>',
#   '<start> 1 एक बाइकर सडकमा घुम्छ। <end>',
#   '<start> 2 रातो साइकलमा सवार एक व्यक्ति धेरै पैदल यात्रीहरूलाई छेउछाउ गर्दै। <end>',
#   '<start> 3 हेलमेटमा सुन्तला रंगको केही बोकेको मानिस व्यस्त वातावरणमा बाइक चलाउँदै। <end>',
#   '<start> 4 मानिस साइकलमा सवार हुन्छ जसरी अरू मानिसहरू हिँड्छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3259119085_21613b69df.jpg': ['<start> 0 एउटा समूह हिउँमा सुतेको बेला नीलो हिउँको स्लेजमा कोही तिनीहरूमाथि उफ्रन्छ। <end>',
#   '<start> 1 मानिसहरूको एउटा समूह हिउँमा सुतिरहेको छ, जबकि अर्को व्यक्तिले तिनीहरूलाई हाम फालेको छ। <end>',
#   '<start> 2 एक व्यक्तिले धेरै मानिसहरूमाथि स्लेज चढाउँछन्। <end>',
#   '<start> 3 एउटा स्लेडरले हिउँमा लडिरहेका अन्य बच्चाहरूमाथि हाम फालेको छ। <end>',
#   '<start> 4 एउटा केटाले आफ्नो स्लेजले हिउँमा सुतिरहेका अरू केटाहरूमाथि हामफाल्यो, जबकि एउटा केटा एउटा छेउमा बसेको थियो। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/530454257_66d58b49ee.jpg': ['<start> 0 क्यामोफ्लाज ज्याकेट लगाएको केटाले प्रदर्शनमा धेरै पहेँलो हाँसहरू देखेको छ। <end>',
#   '<start> 1 एउटा सानो केटा, छलावरण ज्याकेटमा, धेरै पहेँलो रबर बतखहरूको प्रदर्शनलाई हेर्छ। <end>',
#   '<start> 2 एक जवान केटा रबरको हाँसको प्रदर्शनी हेर्दैछ। <end>',
#   '<start> 3 आर्मी गियर लगाएको एउटा जवान केटा बजारमा रबरको डकी उठाउँदै छ। <end>',
#   '<start> 4 सानो केटा पहेंलो रबर बतखको प्रदर्शन हेर्दै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2600170955_bf30c5d5c0.jpg': ['<start> 0 हरियो शर्ट लगाएको केटाले किनमेल कार्टलाई धक्का दिइरहेको छ जसमा पहेँलो शर्ट लगाएको केटा सवार छ। <end>',
#   '<start> 1 एक उत्साही केटाले मुस्कुराएको केटा भएको किनमेल कार्टलाई धकेल्छ। <end>',
#   '<start> 2 एउटा केटाले अर्को सानो केटाको साथमा सपिङ कार्टलाई धकेल्छ। <end>',
#   '<start> 3 पार्किङमा दुई जना केटा किनमेल कार्टसँग खेलिरहेका छन्। <end>',
#   '<start> 4 दुई साना केटाहरू पार्किङमा किनमेल कार्टमा खेलिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3187117682_986ffd6b67.jpg': ['<start> 0 कालो कलर र सुनको ट्याग लगाएको खैरो र सेतो कुकुरले आफ्नो नाकबाट हिउँ चाटिरहेको छ। <end>',
#   '<start> 1 हिउँ पर्दा ओठ चाटिरहेको कुकुर। <end>',
#   '<start> 2 हिउँले धूलोले भरिएको एउटा कुकुरले नाक चाट्छ। <end>',
#   '<start> 3 एउटा सेतो र खैरो कुकुरले जाडोमा आफ्नो ओठ चाट्छ। <end>',
#   '<start> 4 खैरो र सेतो कुकुरले आफ्नो चिसो नाकबाट हिउँ चाट्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3487131146_9d3aca387a.jpg': ['<start> 0 पुरुषहरूको एउटा समूह एउटा रूखको छेउमा उभिएको छ जसरी एउटा रेसिङ कारले तिनीहरूको छेउमा बजरी सडकमा धूलोको बादल उठाउँछ। <end>',
#   '<start> 1 रेस कारले ग्राभल ट्र्याकमा माटो र धुलो उठाउँछ। <end>',
#   '<start> 2 धेरै मानिसहरु कार को भारी धुवाँ हेरेर उभिन्छन्। <end>',
#   '<start> 3 मानिसहरूले फोहोरको माध्यमबाट रेस कारको गति हेरिरहेका छन्। <end>',
#   '<start> 4 धुलोको बादल छेउबाट गुज्रिरहेको धुलो रेसिङ कार हेरिरहेका छ जना दर्शक। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2657663775_bc98bf67ac.jpg': ['<start> 0 एउटी केटी समुद्र तटमा पानीमाथि हाम फाल्छिन्। <end>',
#   '<start> 1 बैजनी ट्याङ्क टप लगाएर समुद्र तटको किनारमा दौडिरहेको एक्लो व्यक्ति <end>',
#   '<start> 2 एउटी महिला समुद्र तट पार गर्दै। <end>',
#   '<start> 3 महिला बैजनी रंगको शर्ट लगाएर समुद्र तटमा दौडिरहेकी छिन्। <end>',
#   '<start> 4 समुद्र तटमा महिला, पानीबाट रूखहरूमा दौडदै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/1425013325_bff69bc9da.jpg': ['<start> 0 दुई ठूला जर्मन शेफर्ड कुकुरहरू पानीमा खेल्छन्। <end>',
#   '<start> 1 दुईवटा कालो कुकुर समुद्र तटमा छरपस्ट छन्। <end>',
#   '<start> 2 दुईवटा कुकुरहरू समुद्रको किनारमा एक अर्कासँग खेलिरहेका छन्। <end>',
#   '<start> 3 दुईवटा कुकुर समुद्र तटमा पानीमा खेल्दै <end>',
#   '<start> 4 तालमा दुई कुकुर सँगै खेल्छन् <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3400082864_9c737c1450.jpg': ['<start> 0 नीलो हेडब्यान्ड र सेतो शर्ट लगाएको मान्छे टेनिस खेल्छ। <end>',
#   '<start> 1 एक खेलाडीले उसले प्रहार गरेको टेनिस बललाई भीडले हेर्दै उडिरहेको हेरिरहेको छ। <end>',
#   '<start> 2 टेनिस खेलमा बल ब्याकह्यान्ड गर्न तयार हुँदै टेनिस खेलाडी। <end>',
#   '<start> 3 मिड स्विङमा टेनिस खेलाडी। <end>',
#   '<start> 4 खेलको बीचमा टेनिस खेलाडी। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/751737218_b89839a311.jpg': ['<start> 0 एक केटाले आफ्नो पानीको बोतलले अर्को व्यक्तिमाथि पानी फाल्ने प्रयास गर्छ। <end>',
#   '<start> 1 रातो शर्ट लगाएको केटाले महिलाको खुट्टामा पानी छर्किरहेको छ। <end>',
#   '<start> 2 बोतल बोकेको केटा जेठी केटीसँग खेल्दै छ। <end>',
#   '<start> 3 एउटा जवान केटाले पानीको बोतलले बूढो मानिसलाई छर्किरहेको छ <end>',
#   '<start> 4 हाँसिरहेको केटाले पानीको बोतल समातेको छ भने भिजेको पाइन्ट लगाएकी एउटी महिला नजिकै हिंडिरहेकी छिन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/414568315_5adcfc23c0.jpg': ['<start> 0 गुलाबी हेडब्यान्ड र नीलो शर्ट लगाएकी एउटी केटी नीलो प्लास्टिक र धातुको कचौरामा चपस्टिक्स लगाएर ड्रम बजाइरहेको छ। <end>',
#   '<start> 1 एउटी सानो एशियाली केटी प्यानमा पिट्दै। <end>',
#   '<start> 2 एक जवान चिनियाँ केटी दुई चपस्टिक, एउटा भाँडो र नीलो प्लास्टिकको कचौराले ड्रम बजाउँदै। <end>',
#   '<start> 3 गुलाबी हेडब्यान्ड लगाएकी एउटी युवतीले चपस्टिक्सले थाल र प्यानमा हिर्काउँछिन्। <end>',
#   '<start> 4 बच्चाले भान्साको भान्साको सामानमा चपस्टिक प्रयोग गरिरहेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3325974730_3ee192e4ff.jpg': ['<start> 0 एक स्नोबोर्डर हिउँले भरिएको र्\u200dयाम्पबाट हावामा माथि उफ्रन्छ। <end>',
#   '<start> 1 एक स्नोबोर्डर र्\u200dयाम्पबाट जम्प गर्दै। <end>',
#   '<start> 2 स्नोबोर्डमा मानिस हावामा उचाईमा ट्रिक प्रदर्शन गर्दै। <end>',
#   '<start> 3 बैजनी कोट लगाएको व्यक्ति स्नोबोर्डमा जम्प गर्दै। <end>',
#   '<start> 4 स्नोबोर्डर बरफको ल्यान्डस्केपमा अग्लो र्याम्पबाट हाम फालेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2630806789_6835bbae95.jpg': ['<start> 0 तालमा रहेका अन्य दुई क्यानो तर्फ लक्षित सुन्तला रंगको क्यानो। <end>',
#   '<start> 1 पहाडी तालमा धेरै सुन्तला केकेकरहरू पङ्क्तिबद्ध छन्। <end>',
#   '<start> 2 पृष्ठभूमिमा पहाडको साथ पानीमा तीन कयाकहरू बाहिर छन्। <end>',
#   '<start> 3 दुईवटा क्यानोहरू पानी पार गर्छन्, तिनीहरूको पछाडि केही घरहरू छन्। <end>',
#   '<start> 4 कयाकबाट देखिने पहाडको दृश्य। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2715035273_8fc8b1291c.jpg': ['<start> 0 महिलाहरूको एउटा समूह रातमा सडकमा हिंड्छ। <end>',
#   '<start> 1 तीन जना महिला साँझको लागि ठूलो शहरमा बाहिर निस्के। <end>',
#   '<start> 2 दुई केटीहरू दुई केटाहरूलाई नियोन बत्ती भएको सडकको रूखबाट पार गर्दै। <end>',
#   '<start> 3 दुई जना महिला राति शहरको सडकमा हिंड्दै छन्। <end>',
#   '<start> 4 महिलाहरू रातमा नियोन बत्तीहरू मुनि हिडिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/303795791_98ebc1d19a.jpg': ['<start> 0 एउटा सानो कुकुरले अर्कोलाई घाँसमा पछ्याउँछ। <end>',
#   '<start> 1 दुईवटा कुकुर घाँसमा दौडन्छन्। <end>',
#   '<start> 2 खैरो दाग भएका दुईवटा साना सेतो कुकुरहरू घाँसमा दौडिरहेका छन्। <end>',
#   '<start> 3 दुईवटा साना सेतो र खैरो कुकुरहरू घाँसमा एकअर्कालाई पछ्याइरहेका छन्। <end>',
#   '<start> 4 दुईवटा दाग भएका कुकुरहरू मैदानबाट दौडिरहेका छन् <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3263141261_db3a4798b5.jpg': ['<start> 0 नीलो पहिरनमा भएको केटा नीलो पहिरिएको महिलाबाट भाग्छ। <end>',
#   '<start> 1 एउटी महिला एउटा सानो केटोलाई पछ्याउँदै छिन्। <end>',
#   '<start> 2 नीलो ज्याकेट लगाएको एउटा सानो केटा दौडिरहेको छ र एउटी महिलाले खेदेको छ। <end>',
#   '<start> 3 नीलो पहिरनमा भएको एउटा सानो केटालाई नीलो पहिरनमा एउटी महिलाले खेदेको छ। <end>',
#   '<start> 4 एउटा जवान केटा आफ्नो आमासँग पार्कमा खेलिरहेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3027009366_c8362521e8.jpg': ['<start> 0 पुरुषहरूको समूह मैदानमा फुटबल खेल्दै। <end>',
#   '<start> 1 रातो वर्दीमा एक जना सेतो वर्दीमा एक जनाले बललाई किक गर्न खोज्दा हावामा उफ्रन्छ। <end>',
#   '<start> 2 फुटबल खेलको क्रममा, एक जना मानिस हावामा हुन्छ र अर्को एक खुट्टा तल हुन्छ। <end>',
#   '<start> 3 सेतो रंगको फुटबल खेलाडीले रातो रंगको खेलाडीलाई आकाशमा बलको लागि चुनौती दिइरहेको छ। <end>',
#   '<start> 4 दुई फुटबल टोलीहरू खेलिरहेका छन्, एउटा सेतो र अर्को रातोमा। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3183195185_cd0ff994a1.jpg': ['<start> 0 एउटा मानिस र एक केटा ढुङ्गाको पर्खालमा आफ्नो पिठ्यु टेकेर बसिरहेका छन्, त्यो मानिस बाँसुरी बजाइरहेको छ। <end>',
#   '<start> 1 एउटा मानिस र एउटा सानो केटा ढुङ्गाको पर्खालमा बसेर आराम गरिरहेका छन्। <end>',
#   '<start> 2 बाँसुरी बोकेको मान्छे र केटा रातो पर्खालमा सडकमा बसिरहेका छन्। <end>',
#   '<start> 3 रातो चट्टानको पर्खाल अगाडि भुइँमा बसिरहेका मानिस र जवान बच्चा। <end>',
#   '<start> 4 मानिस र केटा चट्टानको पर्खालको छेउमा भुइँमा बसिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/561179890_af8e31cb2e.jpg': ['<start> 0 दाह्री भएको मानिस झोला बोकेको ढुङ्गाको खाडी र पुलको अगाडि ट्राइपड समातेको। <end>',
#   '<start> 1 न्यानो लुगा लगाएको मानिस नदी पार गर्ने पुलको अगाडि उभिएको छ। <end>',
#   '<start> 2 चट्टानी खोलाको छेउमा काठको पुलको अगाडि उभिरहेको मान्छे। <end>',
#   '<start> 3 मानिस बाहिर एउटा चट्टानी खोलाको छेउमा हिंडिरहेको छ। <end>',
#   '<start> 4 जुँगा, टोपी र झोला बोकेका एकजना मानिस पानी पार गर्ने पुलको छेउमा उभिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/494921598_af73bda568.jpg': ['<start> 0 एउटा बच्चा आइस हक्की खेल्दै छ <end>',
#   '<start> 1 आइस रिंकमा खेल्दै युवा हक्की खेलाडी <end>',
#   '<start> 3 हक्की खेलाडी पकलाई हिर्काउँदै बरफमा स्केटिङ गर्दैछ। <end>',
#   '<start> 4 दुई जना मानिस आइस हक्की खेल्दै छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3535372414_4c51c86fc4.jpg': ['<start> 0 गुलाबी फूलहरूले ढाकेको ठूलो झाडीको अगाडि उभिरहेका एउटी वृद्ध महिला र जवान केटी। <end>',
#   '<start> 1 एउटी महिला एउटी सानो केटीसँग फूलको झाडीको अगाडि पोज दिँदै। <end>',
#   '<start> 2 वृद्ध महिला सानी केटीको काँधमा हात राख्दै, पृष्ठभूमिमा बिरुवा। <end>',
#   '<start> 3 बूढी महिला र सानी केटी बैजनी फूलहरूको अगाडि उभिए। <end>',
#   '<start> 4 ती महिला एउटी केटीसँग बगैंचामा उभिरहेकी छिन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3004287781_c041c09c16.jpg': ['<start> 0 मानिसहरूको समूह आफ्नो हातले उत्साहित अभिव्यक्तिहरू बनाउँदै <end>',
#   '<start> 1 कुनै चीजको लागि धेरै उत्साहित देखिने मानिसहरूको समूह बाहिर उभिन्छ। <end>',
#   '<start> 3 धेरै युवाहरूले ताली र हर्षोल्लास गरेर उत्सव मनाउँछन्। <end>',
#   '<start> 4 समूहले क्यामेराको लागि अनुहार र हात इशाराहरू बनाउँछ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/333973142_abcd151002.jpg': ['<start> 0 एउटा कालो कुकुरले रुखको हाँगालाई जङ्गलमा बोकेको छ। <end>',
#   '<start> 1 एउटा सानो हाँगा समातेको कालो कुकुर। <end>',
#   '<start> 2 एउटा खैरो र कालो कुकुरले जङ्गली क्षेत्रमा आफ्नो मुखमा लामो लट्ठी बोकेको छ। <end>',
#   '<start> 3 एउटा कुकुरले ठूलो लट्ठी बोकेको छ। <end>',
#   '<start> 4 एक रोटवेइलरले आफ्नो मुखमा धेरै लामो लट्ठी बोकेर जङ्गलमा जान्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2278110011_ba846e7795.jpg': ['<start> 0 सुन्तला रङमा एउटा केटा बुलबुलेमा खेल्छ। <end>',
#   '<start> 1 जीन्स र सुन्तला रंगको शर्ट लगाएको केटा हावामा बुलबुले पछ्याउँदै। <end>',
#   '<start> 2 एउटा बच्चाले बाहिर बुलबुले उडाउँछ। <end>',
#   '<start> 3 सुन्तला रंगको शर्ट लगाएको एउटा सानो केटा बाहिर बुलबुलेसँग खेलिरहेको छ। <end>',
#   '<start> 4 एउटा जवान केटा बुलबुलेबाट दौडिरहेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3464871350_3f2d624a9c.jpg': ['<start> 0 एउटा चालक टोली पेन्स्के रेस कारमा बसिरहेको छ। <end>',
#   '<start> 1 सुन्तला रंगको हेलमेट लगाएको रेस कार चालक रेसवेमा टोली पेन्स्के इन्डी कारमा बसिरहेको छ। <end>',
#   '<start> 2 एउटा रेस कार खाडलमा बस्छ। <end>',
#   '<start> 3 रेस कार चालक दौड सुरुको लागि तयार हुँदैछ। <end>',
#   '<start> 4 रेसिङ कारले TEAM PENSKE लाई ट्र्याक, ब्यानर र पृष्ठभूमिमा दर्शकहरूलाई चिन्ह लगाइयो। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3582914739_bef2828a06.jpg': ['<start> 0 सेतो शर्ट लगाएकी एक स्केटर महिला ट्र्याकमा स्केटिंग गरिरहेकी छिन् र अरूले हेरिरहेका छन्। <end>',
#   '<start> 1 खैरो वर्दीमा एउटी महिला रोलर डर्बीमा भाग लिन्छिन्। <end>',
#   '<start> 2 हेलमेट लगाएकी एउटी महिला रोलर्सस्केटिङ प्रतियोगितामा छिन्। <end>',
#   '<start> 3 खैरो हेलमेट र कालो सेफ्टी प्याड लगाएकी एउटी महिला फोटोग्राफरलाई छेउमा स्केट गर्दै। <end>',
#   '<start> 4 खेलाडीले सुरक्षात्मक गियर लगाएका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3325157569_8084ab3293.jpg': ['<start> 0 बास्केटबल खेलाडीले गोल गर्ने लक्ष्य राख्छ। <end>',
#   '<start> 1 बास्केटबल खेलाडी शूट गर्न तयार हुन्छ। <end>',
#   '<start> 2 एक बास्केटबल खेलाडीले बास्केटबल शूट गर्न हावामा हाम फालेको छ। <end>',
#   '<start> 3 सेतो पहिरनमा बास्केटबल खेलाडी बल फाल्न उफ्रदै, दर्शक पछाडि। <end>',
#   '<start> 4 त्यहाँ एक कलेज बास्केटबल खेलाडीले गोली हानेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2257294002_0073263c54.jpg': ['<start> 0 परिवारका केटाकेटीहरू पर्खँदा खेल्छन्। <end>',
#   '<start> 1 तीन एसियाली केटाकेटीहरू नाचिरहेका छन् जबकि एक जना मानिस हेरिरहेका छन्। <end>',
#   '<start> 2 तीन बालबालिका सार्वजनिक स्थानमा जम्पिङ ज्याक गर्छन् जबकि एकजना मानिस बसेर हेर्छन्। <end>',
#   '<start> 3 तीन बच्चाहरू हाम फाल्दै गर्दा एक वृद्ध मानिस नजिकैको कुर्सीहरूको पङ्क्तिबाट हेर्दै। <end>',
#   '<start> 4 तीन साना केटाकेटीहरू हामफाल्छन् जबकि एक वृद्ध मानिस आफ्नो सिटबाट हेर्छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/377872472_35805fc143.jpg': ['<start> 0 एउटा कुकुर उभिएको छ भने अन्य दुई कुकुर हिउँमा दौडिरहेका छन्। <end>',
#   '<start> 1 तीनवटा कुकुरहरू हिउँमा खेलिरहेका छन्। <end>',
#   '<start> 2 तीनवटा कुकुरहरू हिउँमा एकअर्कालाई पछ्याउँदै। <end>',
#   '<start> 3 तीनवटा कुकुर हिउँमा खेल्छन्। <end>',
#   '<start> 4 दुईवटा कुकुर हिउँमा सँगै खेल्छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3398276602_c7d106c34f.jpg': ['<start> 0 ह्वीलचेयरमा बसेको एक घरबारविहीन मानिसले एउटा कपलाई मानिसलाई केही परिवर्तन गर्नको लागि बाहिर समातिरहेको छ <end>',
#   '<start> 1 एकजना मानिसले प्यानह्यान्डलरलाई दान दिन्छन्। <end>',
#   '<start> 2 ह्वीलचेयरमा बाँधिएको व्यक्ति एक यात्रीबाट टिप प्राप्त गर्दै। <end>',
#   '<start> 3 ह्वीलचेयरमा बसेका बुढा मानिस ह्यान्डआउटको लागि भिख माग्दै <end>',
#   '<start> 4 ट्यान सर्ट लगाएको मानिसले ह्वीलचेयर र टोपीमा मानिसलाई दिन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/1096395242_fc69f0ae5a.jpg': ['<start> 0 खेलौना बन्दुक भएको केटा। <end>',
#   '<start> 1 सुन्तला रंगको सर्ट लगाएको एउटा सानो केटा खेलौनासँग खेल्दै। <end>',
#   '<start> 2 एउटा जवान केटाले आफ्नो खुट्टा पसारेको फायरप्लेसको अगाडि क्यामेरामा खेलौनाको लक्ष्य राख्छ। <end>',
#   '<start> 3 एउटा सानो बच्चा आफ्नो नयाँ लाइट-अप खेलौनासँग खेलिरहेको छ। <end>',
#   '<start> 4 खेलौना बन्दुक बोकेको केटाले क्यामेरातिर औंल्यायो। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2836808985_b26e4ca09e.jpg': ['<start> 0 फ्ल्यानेल सर्ट र कालो प्यान्ट लगाएको एउटा मानिस जहाजमा बसेर रेलिङबाट बाहिर हेरिरहेको छ। <end>',
#   '<start> 1 फ्लानेल शर्ट लगाएको एक मानिस धातुको बार पछाडि बसिरहेको छ। <end>',
#   '<start> 2 एक जना मानिस आफ्नो खुट्टा पोलमा राखेर मुस्कुराउँदै बस्छ। <end>',
#   '<start> 3 भुइँमा बसेको एकजना मानिसले आफ्नो खुट्टा रेलिङमा उचाल्दै छ। <end>',
#   '<start> 4 प्लेड सर्ट लगाएको एक युवक डुङ्गाको डेकमा बसिरहेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3558251719_3af5ae2d02.jpg': ['<start> 0 एउटा खैरो कुकुर पछाडिको खुट्टामा उभिएको मानिसको हातमा केही छिर्न खोजिरहेको छ। <end>',
#   '<start> 1 एउटा मानिस र कुकुर मैदानमा खेल्दै छन् <end>',
#   '<start> 2 एउटा मानिस र कुकुर घाँसमा उभिएका छन्। <end>',
#   '<start> 3 एउटा मानिस लट्ठी समातेर कुकुरसँग खेल्दै। <end>',
#   '<start> 4 मानिसको पट्टामा एउटा कुकुर छ र उसले त्यसलाई पछाडिको खुट्टामा उभिन सिकाएको देखिन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3613955682_3860e116cf.jpg': ['<start> 0 टोलीका खेलाडीहरूको समूह सँगै पोज दिइरहेका छन्। <end>',
#   '<start> 1 फुटबल टोलीले तस्विरको लागि पोज दियो। <end>',
#   '<start> 2 रातो लुगा लगाएको फुटबल टोली सँगै पोज दिँदै। <end>',
#   '<start> 3 खेलकुद टोली मैदानमा पोज दिँदै। <end>',
#   '<start> 4 खेलकुद टोली पृष्ठभूमिमा भीडको साथ मैदानमा पोज दिँदै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3578981202_efef47e264.jpg': ['<start> 1 घुमाउरो सुनौलो कपाल र फूलको पर्दा भएको हाँसेको बच्चाको डबल एक्सपोजर <end>',
#   '<start> 2 घुमाउरो कपाल भएको सानो बच्चालाई वयस्कले समातिरहेको छ। <end>',
#   '<start> 3 कसैले हाँसिरहेको नाङ्गो बच्चा समातेको छ। <end>',
#   '<start> 4 बच्चाले नुहाउन रमाइलो गर्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2991993027_36ac04e9a0.jpg': ['<start> 0 जोम्बीको रूपमा लुगा लगाएका मानिसहरूको समूह। <end>',
#   '<start> 1 फेसपेन्ट लगाएका मानिसहरूको ठूलो समूह बाहिर भेला हुन्छ। <end>',
#   '<start> 2 यस पार्टीमा सबैजना जोम्बीको रूपमा लुगा लगाउँछन्। <end>',
#   '<start> 3 धेरै मानिसहरूले रातमा अनुहार रंगाउँछन्। <end>',
#   '<start> 4 जोम्बी पोशाकमा सजिएका मानिसहरू वरिपरि उभिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/368393384_86defdcde8.jpg': ['<start> 0 एक केकर नदीमा डुब्छ। <end>',
#   '<start> 1 क्यानोमा एक व्यक्ति जंगली पानीमा र्याफ्टिङ गर्दैछ। <end>',
#   '<start> 2 एक व्यक्ति आफ्नो पहेंलो कयाकमा पानीमा आधा डुबेको छ। <end>',
#   '<start> 3 एउटी महिलाले आफ्नो कयाक नाकलाई पानीमा राखेकी छिन्। <end>',
#   '<start> 4 पहेँलो कयाकमा भएको मानिस असभ्य पानीमा प्याडलिङ गर्दैछ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2236016316_f476cbbf06.jpg': ['<start> 0 हरियो शर्ट लगाएकी एउटी केटी जिममा दौडिरहेको छ। <end>',
#   '<start> 1 हरियो शर्ट लगाएकी एउटी केटी बास्केटबल खेल्दै। <end>',
#   '<start> 2 केटाकेटीहरू अदालतभित्र दौडिरहेका छन्। <end>',
#   '<start> 3 युवा बास्केटबल खेलाडी अगाडिको कोर्टमा सर्छ। <end>',
#   '<start> 4 टिमका दुई खेलाडी हरियो शर्ट लगाएर कोर्टमा दौडिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/750196276_c3258c6f1b.jpg': ['<start> 0 एउटा केटा केही पाइला नजिकै दौडन्छ। <end>',
#   '<start> 1 एउटा सानो केटा केही ठोस पाइलाहरूमा दौडिरहेको छ। <end>',
#   '<start> 2 हरियो शर्ट र हरियो स्वेट प्यान्ट लगाएको एउटा जवान केटा कंक्रीटको भुइँमा दौडिरहेको छ। <end>',
#   '<start> 3 एउटा जवान केटा सिमेन्टको सिँढीबाट तल दौडिरहेको छ। <end>',
#   '<start> 4 सानो केटा दौडिरहेको छ र मुस्कुराउँदै छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/504904434_889f426c6e.jpg': ['<start> 0 एउटा केटा खेलौना फुटबल समातेर पक्की बाटोमा दौडिरहेको छ। <end>',
#   '<start> 1 एउटा केटा एउटा सानो प्लाष्टिकको फोम फुटबल बोकेर एउटा घरको छेउबाट दौडन्छ। <end>',
#   '<start> 2 एउटा केटा पक्की हिड्ने बाटोमा सानो फुटबल लिएर दौडिरहेको छ। <end>',
#   '<start> 3 एक व्यक्ति सानो फुटबल लिएर दौडन्छ। <end>',
#   '<start> 4 एउटा जवान केटा फुटपाथमा सानो फुटबल समातेर दौडिरहेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3054200086_657d4398e8.jpg': ['<start> 0 एक हक्की खेलाडीले शट बनाउँछ। <end>',
#   '<start> 1 एक हक्की खेलाडी पकको साथ अगाडि स्केट गर्दै विपक्षीले आइस रिंकमा नजिकैबाट हेरेको रूपमा। <end>',
#   '<start> 2 कालो र सेतो पहिरन लगाएका एक हक्की खेलाडीले आफ्नो लठ्ठी बरफमा सर्छ। <end>',
#   '<start> 3 आइस हक्की खेलाडीले विपक्षी खेलाडी हेरेर पकलाई गोली हानेको छ। <end>',
#   '<start> 4 दुई जना पुरुष बरफमा हक्की खेल्दै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/253762507_9c3356c2f6.jpg': ['<start> 0 एक सुरक्षाकर्मीले अर्कोले आफ्ना सामानहरू ल्याउँदा ढोकामा पहरा दिन्छ। <end>',
#   '<start> 1 एक सबवे कार्यकर्ता कारको छेउमा उभिएको छ जसमा धेरै फोहोर झोलाहरू छन्। <end>',
#   '<start> 2 कसैले एउटा ठूलो कालो झोलालाई सबवेमा तानेको छ। <end>',
#   '<start> 3 सबवे कारबाट बाहिर निस्केको बम छ। <end>',
#   '<start> 4 सबवेको ढोकाबाट फोहोर फाल्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/269650644_059a84ece5.jpg': ['<start> 0 मानिसहरूको एउटा समूह एउटा ठूलो शहरमा आइस स्केटिङ गर्दैछ। <end>',
#   '<start> 1 हिउँदमा आइस स्केटिङ पार्क, धेरै मानिसहरूको साथ। <end>',
#   '<start> 2 मानिसहरूले भरिएको बाहिरी आइस स्केटिङ रिंक। <end>',
#   '<start> 3 मानिसहरू शहरी बाहिरी आइस स्केटिङ रिंकमा स्केट गर्दै <end>',
#   '<start> 4 बाहिरी आइस स्केटिङ रिंक प्रयोग गर्ने मानिसहरू। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2091171488_c8512fec76.jpg': ['<start> 0 गुलाबी पन्जा र खैरो ज्याकेट लगाएकी एउटी महिला हिउँमा मुस्कुराउँदै छिन्। <end>',
#   '<start> 1 पृष्ठभूमिमा मानिसहरूसँग हिउँमा उभिएकी महिला। <end>',
#   '<start> 2 वसन्त कोट र बैजनी पन्जा लगाएकी एउटी युवती झरिरहेको हिउँमा उभिरहेकी छिन्। <end>',
#   '<start> 3 हिउँ परेको बेला एउटी युवती जाडोको लुगा लगाएर खुसी देखिन्छिन्। <end>',
#   '<start> 4 गुलाबी पन्जा लगाएकी युवा एसियाली महिला हिउँमा उभिरहेकी छिन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3708177171_529bb4ff1d.jpg': ['<start> 0 एक केटा बाहिर स्केटबोर्डमा फूलको झाडीमाथि हाम फाल्दै छ। <end>',
#   '<start> 1 कालो लुगा लगाएको स्केटबोर्डर बेन्चमाथि उफ्रन्छ। <end>',
#   '<start> 2 एक स्केटबोर्डरले काठको बेन्चबाट जम्प गर्दैछ। <end>',
#   '<start> 3 खैरो कपाल भएको एक युवा आफ्नो स्केटबोर्डको साथ बेन्चमा ओली गर्दै छन्। <end>',
#   '<start> 4 स्केटबोर्डर विज्ञापन सहितको बेन्चद्वारा हावामा <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2384626662_67cdd87694.jpg': ['<start> 1 एउटा बच्चा र वयस्क, प्रत्येक टोपी लगाएका, समुद्रको छेउमा खेल्छन्। <end>',
#   '<start> 2 एक महिला र केटा समुद्र तटमा खेल्दै। <end>',
#   '<start> 3 दुई बच्चाहरू समुद्रको किनारमा समुद्रतिर दौडिरहेका छन्। <end>',
#   '<start> 4 समुद्र तटमा दुई बच्चाहरू। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3621717946_d96f8a6012.jpg': ['<start> 0 एक व्यक्तिले पोखरीमा आफ्नो प्रतिद्वन्द्वीलाई नेटमा पहेंलो भलिबल प्रहार गर्छ। <end>',
#   '<start> 1 मानिसहरू पानी भलिबल खेलिरहेका छन्। <end>',
#   '<start> 2 दुई जना मानिस पोखरीमा वाटर भलिबल खेल्दै छन्। <end>',
#   '<start> 3 दुई जना पौडीबाज पहेंलो बल र जालको साथ पानीको खेल खेल्दै छन्। <end>',
#   '<start> 4 पोखरीमा दुई पौडी खेल्ने पानी पोलो बलले जालमा खेल्छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3439128755_84409b8823.jpg': ['<start> 0 गुलाबी शर्ट लगाएको खैरो कुकुरले सेतो चिज चपाउँछ भने पहेँलो घडीमा खैरो कुकुरले हेर्छ। <end>',
#   '<start> 1 गुलाबी रंगको शर्ट लगाएको खैरो कुकुरले पहेंलो शर्ट लगाएको खैरो कुकुरलाई पछ्याउँछ। <end>',
#   '<start> 2 गुलाबी शर्ट लगाएको कुकुर मुखमा सेतो र पहेँलो शर्ट लगाएको कुकुर। <end>',
#   '<start> 3 कपडा लगाएका दुई कुकुरहरू समतल काटिएको खेतमा छन्। <end>',
#   '<start> 4 दुई कुकुरहरू खेतमा वस्तु ल्याउँदै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/930748509_8ca5cf5c24.jpg': ['<start> 0 पार्कमा छातीमा कुकुर पाल्ने मान्छे। <end>',
#   '<start> 2 एक युवकले कुकुरको घाँटी खरानी हान्यो। <end>',
#   '<start> 3 एक जवान मानिस बाहिर कुकुर लिएर बसेको छ। <end>',
#   '<start> 4 एउटा जवान मानिस बसेर आफ्नो कुकुर पाइरहेको छ <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2719102611_fef453bf30.jpg': ['<start> 0 कालो र सेतो पोशाक लगाएको एक मानिस मोटरसाइकलमा स्टन्ट गर्दै उभिएको छ। <end>',
#   '<start> 1 एक मोटरसाइकल सवार आफ्नो बाइकको माथि उभिएको छ। <end>',
#   '<start> 2 एक मोटरसाइकल सवार आफ्नो सेतो मोटरसाइकलको सिटमा बालुवा उठाउन थाल्छ। <end>',
#   '<start> 3 कोही कालो र सेतो मोटरसाइकलमा छन् र आफ्नो खुट्टा सिटमा राखेका छन्। <end>',
# ...
#   '<start> 1 एउटी आमा आफ्नो छोरालाई रेस्टुरेन्टमा खाना खुवाउन खोजिरहेकी छिन्। <end>',
#   '<start> 2 एउटा रेस्टुरेन्टको टेबलमा एउटी केटीले एउटा सानो केटालाई खान खोज्दै छिन्। <end>',
#   '<start> 3 पहेंलो पहिरन लगाएकी एउटी युवती टेबलमा एउटा सानो बच्चालाई खुवाउँदै छिन्। <end>',
#   '<start> 4 टेबुलमा बसेकी महिला आफ्नो काखमा बसेको बच्चालाई खुवाउँदै <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3470129475_9e58b6742c.jpg': ['<start> 0 एक केटाले आफ्नो बाइकमा अन्य बच्चाहरूले हेर्दा ट्रिक गर्छ। <end>',
#   '<start> 1 एक केटा साइकलमा हावामा <end>',
#   '<start> 2 एक पुरुष आफ्नो बाइकमा हावामा ट्रिक गर्दै। <end>',
#   '<start> 3 एक मानिसले आफ्नो साइकल सिमेन्टको झुकाव माथि उचालेको छ। <end>',
#   '<start> 4 BMX बाइकमा हावामा एक जना मानिस <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3710468717_c051d96a5f.jpg': ['<start> 0 दुई बालबालिका र एउटा कालो कुकुर हिउँमा खेलिरहेका छन्। <end>',
#   '<start> 1 दुई केटाकेटी र एउटा कुकुर हिउँमा हिउँमा खेलिरहेका छन्। <end>',
#   '<start> 2 दुई बालबालिका र एउटा कुकुर हिउँमा दौडिरहेका छन्। <end>',
#   '<start> 3 दुई बच्चा र तिनीहरूको कुकुर हिउँमा खेल्दै। <end>',
#   '<start> 4 दुई बच्चा र एउटा कुकुर हिउँमा खेल्दै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/652542470_60e858da64.jpg': ['<start> 0 एउटी केटी पौडी खेल्नको लागि तयार छिन्। <end>',
#   '<start> 1 नुहाउने सूट र चश्मा लगाएकी एउटी केटी बसेर पर्खिरहेकी छिन्। <end>',
#   '<start> 2 एक जवान पौडीबाज नुहाउने सूटमा बस्छ र अर्को दौडको लागि पर्खिरहेको छ। <end>',
#   '<start> 3 बच्चा स्विम गियर लगाएर बसिरहेको छ। <end>',
#   '<start> 4 प्रतिस्पर्धात्मक पौडी खेल्ने पोशाकमा जवान केटी। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2481367956_8577d2fa98.jpg': ['<start> 0 एउटा बच्चा बारको लागि पुग्छ। <end>',
#   '<start> 1 नेभी नीलो पहिरनमा एउटा सानो केटा खेल मैदानमा बारको लागि पुग्दै। <end>',
#   '<start> 2 एउटा सानो बच्चा बारको लागि पुग्छ। <end>',
#   '<start> 3 केटा नीलो पोलको लागि टाउको माथि पुग्छ। <end>',
#   '<start> 4 सानो केटा खेल क्षेत्रमा निलो बारमा पुग्दैछ, अर्को बच्चा पृष्ठभूमिमा। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3726590391_bc6e729bb6.jpg': ['<start> 0 एक वृद्ध महिला झ्यालमा बसेर रोइरहेकी छिन्। <end>',
#   '<start> 1 एउटी वृद्ध महिला झ्यालमा बसेर पढिरहेकी छिन्। <end>',
#   '<start> 2 एउटी महिला झ्यालको अगाडि किताब पढिरहेकी छिन्। <end>',
#   '<start> 3 एउटी महिला आफ्नो टाउको तल र मुखमा हात राखेर कसैको छेउमा पढिरहेकी छिन्। <end>',
#   '<start> 4 झ्यालको अगाडि एउटी वृद्ध महिला छिन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2822891602_ff61df2ece.jpg': ['<start> 0 सुन्तला रंगको स्नोर्कल मास्क लगाएको केटा पानीमुनि पौडी खेलिरहेको छ। <end>',
#   '<start> 1 एउटा बच्चा स्विम गियर र सुन्तला चश्मा लगाएर पानीमुनि डुबुल्की मार्दै छ। <end>',
#   '<start> 2 केटा सुन्तलाको मास्क लगाएर पानीमुनि पौडी खेल्छ। <end>',
#   '<start> 3 रातो चश्मा लगाएको केटा पानीमुनि पौडिन्छ। <end>',
#   '<start> 4 सानो केटा पानी मुनि पौडिन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2937942758_712be5c610.jpg': ['<start> 0 एक व्यक्ति उस्तै रातो र सेतो साइकलको पङ्क्तिमा उभिरहेको छ। <end>',
#   '<start> 1 एउटी महिला धेरै साइकलको छेउमा बाहिर उभिरहेकी छिन्। <end>',
#   '<start> 2 बाइक र्याक नजिकै उभिएकी महिला। <end>',
#   '<start> 3 एउटी महिला उस्तै रातो साइकलको पङ्क्तिमा उभिरहेकी छिन्। <end>',
#   '<start> 4 बाइक र्याकमा रातो र सेतो बाइकहरूको पङ्क्ति छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3518334317_bc40bae18d.jpg': ['<start> 0 एक पुरुष र एक महिला बाहिरी बजारबाट टाढा हिंड्दै। <end>',
#   '<start> 1 धेरै मानिसहरू ग्रामीण किनमेल क्षेत्रबाट हिंडिरहेका छन्। <end>',
#   '<start> 2 पुरुष मध्य पूर्वी बजारमा हिड्दै। <end>',
#   '<start> 3 पार्क गरिएको मोटर चालित स्कुटरको छेउमा लामो गल्लीबाट धेरै मानिसहरू हिँड्छन्। <end>',
#   '<start> 4 दुई जना मानिस सहरको सडकमा एउटा आर्क मुनि हिंडिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/475778645_65b7343c47.jpg': ['<start> 0 हार्नेस लगाएको एउटा केटा चट्टानको पर्खाल चढ्छ। <end>',
#   '<start> 1 एउटा सानो केटा चढ्ने पर्खालको छेउमा सुरक्षा हार्नेसमा झुण्डिएको छ। <end>',
#   '<start> 2 हार्नेसमा एक जवान केटा ढुङ्गा चढ्दै छ। <end>',
#   '<start> 3 केटा सेतो चट्टानको पर्खाल चढ्दै छ। <end>',
#   '<start> 4 सानो बच्चा सेतो चट्टानको पर्खाल चढ्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2923475135_a6b6e13d26.jpg': ['<start> 0 एउटा खैरो घोडा उसमा सवार भएकोले नीलो बाधामाथि हाम फालेको छ <end>',
#   '<start> 1 घोडा र सवार , बाटोमा अवरोध हाम फाल्दै। <end>',
#   '<start> 2 सेतो पहिरनमा एक व्यक्तिले गेटमा खैरो घोडा हाम फालेको छ। <end>',
#   '<start> 3 जकी र घोडा नीलो बाधामाथि हाम फाल्छन् <end>',
#   '<start> 4 त्यहाँ एक घोडा र सवार एक बाधा माथि उफ्रिदै छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3359551687_68f2f0212a.jpg': ['<start> 0 एउटी केटी सडकमा कार्टव्हील गर्छिन् जबकि मानिसहरू फुटपाथबाट हेर्छन्। <end>',
#   '<start> 1 एक केटी भीडको अगाडि कार्टव्हील गर्दै। <end>',
#   '<start> 2 एउटी महिला फुटपाथमा बसिरहेका अन्य मानिसहरूको भीडको अगाडि पछाडि पल्टिरहेकी छिन्। <end>',
#   '<start> 3 शर्ट्स लगाएको कोही भीडको अगाडि कलंक गर्दैछ। <end>',
#   '<start> 4 कालो शर्ट लगाएका व्यक्तिले सडकमा स्टन्ट प्रदर्शन गर्दा भीडले हेरेको थियो। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3432730942_4dc4685277.jpg': ['<start> 0 दुई जना पुरुष मोटरसाइकल चढ्न तयार हुँदैछन्। <end>',
#   '<start> 1 चर्च नजिकै दुई जना मानिसले रातो मोटरसाइकल पार्क गर्दैछन्। <end>',
#   '<start> 2 दुई मोटरसाइकल र तिनका सवारहरू। <end>',
#   '<start> 3 छालाको लुगा लगाएका दुई जना मानिस मोटरसाइकलको छेउमा उभिरहेका छन्। <end>',
#   '<start> 4 भित्तामा धार्मिक भित्तिचित्रहरू रहेको ठाउँमा दुई जना रातो मोटरसाइकल हेर्छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2428751994_88a6808246.jpg': ['<start> 0 एउटा कालो र सेतो कुकुर हरियो घाँसमा दौडन्छ। <end>',
#   '<start> 1 एउटा खैरो र सेतो कुकुर घाँसमा दौडिरहेको छ। <end>',
#   '<start> 3 एउटा कुकुर मैदानमा दौडन्छ। <end>',
#   '<start> 4 एउटा मुस्कुराउने कुकुर घाँसमा दौडन्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3587009091_37188fd07e.jpg': ['<start> 0 एउटा कुकुर धेरै हाँसहरू नजिकै गहिरो पानीमा पौडी खेलिरहेको छ। <end>',
#   '<start> 1 कुकुर केही पानीमा पौडी खेलिरहेको छ जहाँ केही हाँस पनि पौडी खेलिरहेका छन् <end>',
#   '<start> 2 एउटा कुकुर गहिरो पानीमा तीनवटा हाँसको नजिक पौडी खेल्छ। <end>',
#   '<start> 3 एउटा कुकुर हाँसको नजिक पौडी खेल्छ। <end>',
#   '<start> 4 तीनवटा हाँस र एउटा कुकुर तालमा पौडी खेल्छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3737492755_bcfb800ed1.jpg': ['<start> 0 भारतीय पहिरन लगाएका एक व्यक्तिले ड्रम बजाउँछन्। <end>',
#   '<start> 1 कालो-पहेंलो कार्निवल प्वाँख लगाएको मान्छे, ड्रम बजाउँदै। <end>',
#   '<start> 2 एक परेडमा पोशाकमा ड्रममा एक व्यक्ति। <end>',
#   '<start> 3 भारतीय भेषभूषा लगाएका एकजना मानिस पासोको ड्रम बजाइरहेका छन्। <end>',
#   '<start> 4 कालो र पहेँलो पहिरनमा एकजना मानिस ड्रम बजाउँदै छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2456030728_d3d147e774.jpg': ['<start> 0 नीलो धनु बोकेकी एउटी सानी केटीले आफ्नो नाक टिप्ने क्रममा प्लशी समात्दै। <end>',
#   '<start> 1 कपालमा रिबन लगाएकी एउटी सानी केटीले आफ्नो नाक छोएको छ। <end>',
#   '<start> 2 एक एसियाली केटी आफ्नो नाक माथि औंला लिएर। <end>',
#   '<start> 3 एउटी जवान केटीले आफ्नो नाक उठाइन्। <end>',
#   '<start> 4 नीलो कपाल रिबनले नाक उठाउँदै एसियाली केटी। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2841449931_84a05850ec.jpg': ['<start> 0 गुलाबी जर्सी र सनग्लास लगाएको मान्छे घाममा बसिरहेको छ। <end>',
#   '<start> 1 गुलाबी शर्टमा सनग्लास लगाएको मान्छे। <end>',
#   '<start> 2 एक वृद्ध मानिस बसेर केहि हेर्दै। <end>',
#   '<start> 3 गुलाबी रंगको शर्ट र सनग्लास लगाएको एक वृद्ध मानिस बसिरहेको छ, उनको पछाडि एक महिला। <end>',
#   '<start> 4 मानिसले सनग्लास र गुलाबी शर्ट लगाएको छ <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2306186887_0bd8ed3792.jpg': ['<start> 0 एउटा खैरो कुकुर रातो खेलौनासँग खेलिरहेको छ भने अर्को खैरो कुकुर क्यामेरातिर घुमिरहेको छ। <end>',
#   '<start> 1 कुकुरहरू रातो बलले दौडन र खेल्छन्। <end>',
#   '<start> 2 फ्लपी कान भएका साना खैरो कुकुरहरू रातो बलसँग खेलिरहेका छन्। <end>',
#   '<start> 3 दुईवटा कुकुर, एउटाले मुखमा बल लिएर घाँसबाट दौडिरहेको छ। <end>',
#   '<start> 4 दुईवटा खैरो कुकुर घाँसमा खेलिरहेका छन्, र तीमध्ये एउटाले रातो बल बोकेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2194494220_bb2178832c.jpg': ['<start> 0 एक व्यक्ति पहाडमा कुकुरसँग स्कीजोर गर्दैछ। <end>',
#   '<start> 1 एक व्यक्ति आफ्नो कुकुरसँग स्की गर्दै। <end>',
#   '<start> 2 एक महिला क्रस-कन्ट्री स्कीइङ, खैरो कुकुरसँग। <end>',
#   '<start> 3 एक महिला हिउँले ढाकिएको पहाडमा स्कीइङ गर्दै खैरो कुकुरको साथमा <end>',
#   '<start> 4 खैरो कुकुरले स्कीयरलाई हिउँले ढाकिएको जमिनमा तान्छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3627216820_4952bacbcb.jpg': ['<start> 0 एउटा कुकुर अर्को कुकुरमाथि उफ्रन्छ किनकि दुवै जनावरले एउटै बल समात्न खोजिरहेका छन्। <end>',
#   '<start> 1 दुई कालो र सेतो कुकुरहरू बलसँग खेल्दै। <end>',
#   '<start> 2 दुईवटा कुकुर खेल्दै छन्, एउटा कुकुर दोस्रो कुकुरको माथि हावामा उफ्रिरहेको छ। <end>',
#   '<start> 3 पार्कमा टेनिस बल पछि जम्प गर्दै दुई टेरियरहरू <end>',
#   '<start> 4 दुईवटा सेतो र कालो कुकुरहरू घेरा लगाएको क्षेत्रमा खेल्छन् र हामफाल्छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3415287719_3c776f370e.jpg': ['<start> 0 दुई केटीहरू हावामा उचालिरहेका छन्। <end>',
#   '<start> 1 दुई केटीहरू पाइन रूखहरूको अगाडि उकालो उफ्रिरहेका छन्। <end>',
#   '<start> 2 ब्याकग्राउन्डमा रूखहरू लिएर आकाशमा दुई केटीहरू <end>',
#   '<start> 3 मिड लीपमा दुई केटीहरू, एउटा जीन्स र रातो शर्ट लगाएकी अर्को कालो प्यान्ट फ्लोरल शर्टसहित <end>',
#   '<start> 4 दुई केटीहरू हावामा हाम फाले। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3006094603_c5b32d2758.jpg': ['<start> 0 बराक ओबामाको शर्ट लगाएको मान्छे क्यामेराको लागि मुस्कुराउँदै <end>',
#   '<start> 1 ओबामाको टी-सर्ट लगाएको र कफीको कप समातेको मान्छे। <end>',
#   '<start> 2 एक जवान मानिस ओबामाको टी-शर्टलाई टाउट गर्दै। <end>',
#   '<start> 3 यो कप समातेको र ओबामाको टी-सर्ट लगाएको मान्छे हो। <end>',
#   '<start> 4 यो मानिसले बराक ओबामाको टी-सर्ट लगाएको छ र रक्सी बोकेको छ। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3225296260_2ee72b4917.jpg': ['<start> 0 सुन्तला रेस कारमा दुई जना मान्छे। <end>',
#   '<start> 1 हेलमेट लगाएका दुई जना सुन्तला रंगको कारमा बसिरहेका छन्। <end>',
#   '<start> 2 सुन्तला रंगको रेस कारमा दुई जना सवार छन्। <end>',
#   '<start> 3 हेलमेट लगाएका दुई जना रेस कारमा बसिरहेका छन्। <end>',
#   '<start> 4 सुन्तला रंगको कार चलाउँदै दुई रेसरहरू <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3517127930_5dbddb45f6.jpg': ['<start> 0 बेसबल खेलमा एउटा केटाले बललाई प्रहार गर्छ। <end>',
#   '<start> 1 एक सफ्टबल खेलाडीको टोलीले पिचमा स्विंग गरिरहेको हेर्छ। <end>',
#   '<start> 3 खैरो र सेतो रंगको बेसबल टोलीका एक सदस्य ब्याटमा छन्। <end>',
#   '<start> 4 सफ्टबल खेलाडी पिचमा स्विङ गर्दै <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3442138291_3e75f4bdb8.jpg': ['<start> 0 एउटा केटा कंक्रीटको पहाड तल दौडिरहेको छ। <end>',
#   '<start> 1 कालो शर्ट र नीलो जिन्स लगाएको एउटा सानो केटा बाटोमा हिंड्दै। <end>',
#   '<start> 2 सानो केटा पार्कमा एक दिन रमाइलो गर्दै <end>',
#   '<start> 3 सानो केटा डाउनहिल क्यामेरामा दौडन्छ, ग्याजेबो पृष्ठभूमिमा। <end>',
#   '<start> 4 कालो शर्ट र जिन्स लगाएको सानो बालक बाटोमा दौडियो। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3590647207_2d4ec3f52c.jpg': ['<start> 0 धेरै राष्ट्रको झण्डा बोकेर घोडामा सवार महिलाहरूको समूह <end>',
#   '<start> 1 संयुक्त राज्य अमेरिकाको झण्डा र क्यानडाको झण्डा फहराउँदै काउगर्लहरू <end>',
#   '<start> 2 झण्डा बोकेर घोडामा सवार धेरै मानिसहरू। <end>',
#   '<start> 3 अमेरिकी र क्यानाडाको झण्डा बोकेर रोडियोमा घोडामा सवार दुई महिला। <end>',
#   '<start> 4 महिलाहरू क्यानडा र संयुक्त राज्य अमेरिकाको झण्डा बोकेर मैदानमा घोडा चढिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2257631407_1529b9db39.jpg': ['<start> 0 पसिना र जीन्स लगाएका केही रमाइला केटाकेटीहरू घाँसमा हिडिरहेका छन्। <end>',
#   '<start> 1 कसैको पिठ्युमा एउटी केटी हाँस्दै छ। <end>',
#   '<start> 3 कोही एउटी सानी केटीलाई उल्टो झुन्ड्याउँदै समातेको। <end>',
#   '<start> 4 घाँसमा टाउकोको टुप्पो भएका दुई व्यक्ति। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/1354318519_2f9baed754.jpg': ['<start> 0 एउटा बच्चा हाँसिरहेको छ। <end>',
#   '<start> 1 एउटा बच्चा ऐनामा आफ्नो प्रतिबिम्ब देखेर हाँस्छ। <end>',
#   '<start> 2 बरगन्डी हुडीमा सुनौलो कपाल भएको बच्चा मुस्कुराउँदै। <end>',
#   '<start> 3 रातो हुड लगाएको केटा आफ्नो प्रतिबिम्बबाट टाढा हेर्दै मुस्कुराउँदै छ। <end>',
#   '<start> 4 एउटा बच्चा आफ्नै प्रतिबिम्बको अगाडि क्यामेरातिर फर्केर मुस्कुराउँदै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2661294481_b86058b504.jpg': ['<start> 0 एउटा भीड एउटा सानो डाउनटाउन सेटिङमा मार्च गर्न थाल्छ। <end>',
#   '<start> 1 चिन्हहरू बोकेर सडकमा यात्रा गर्दै मानिसहरूको समूह। <end>',
#   '<start> 2 चिन्ह र ब्यानर लिएर सडकमा हिंडिरहेका मानिसहरूको समूह <end>',
#   '<start> 3 एक विरोध र्\u200dयाली रातो चट्टान लगाएको भवनको छेउमा दुईवटा सडकको चौराहे पार गर्दैछ। <end>',
#   '<start> 4 धेरै मानिसहरू चिन्हहरू समात्छन् र सडकमा मार्च गर्छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2959941749_fa99097463.jpg': ['<start> 0 हक्की खेलाडीहरूको समूह खेलको क्रममा बरफमा सर्दै। <end>',
#   '<start> 1 हक्की खेल्ने पुरुषहरूको समूह। <end>',
#   '<start> 2 हक्की खेल खेल्दै छ। <end>',
#   '<start> 3 एक हक्की गोलकिपर बरफमा सुतिरहेको छ र अन्य खेलाडीहरू उसलाई छेउमा स्केट गर्दै छन्। <end>',
#   '<start> 4 दुई हक्की खेलाडी टोलीहरू बरफमा खेल खेल्दै <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/475042270_719ebe6c48.jpg': ['<start> 0 गोल्डेन रिट्रिभर गुलाबी कलरमा सानो कालो र खैरो कुकुरसँग खेलिरहेको छ। <end>',
#   '<start> 1 एउटा सानो कालो र खैरो कुकुर ठूलो सुन्तला रंगको कुकुरमाथि हाम फाल्दै छ। <end>',
#   '<start> 2 एउटा सानो कालो कुकुर जंगलमा ठूलो खैरो कुकुरसँग लडिरहेको छ। <end>',
#   '<start> 3 कालो र ट्यान कुकुरको टाउको नजिकै खुला मुख भएको खैरो कुकुर। <end>',
#   '<start> 4 दुईवटा कुकुर जंगलको छेउमा खेलिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/3583065748_7d149a865c.jpg': ['<start> 0 एउटा कालो र कालो कुकुर दौडिरहेका छन्। <end>',
#   '<start> 1 एउटा कालो र सेतो कुकुरले घाँसमा ठूलो कुकुरलाई पछ्याउँछ। <end>',
#   '<start> 2 एउटा कुकुरले घाँसमा अर्को कुकुरलाई पछ्याउँछ। <end>',
#   '<start> 3 घाँसमा दौडिरहेका दुईवटा चरा कुकुरहरू। <end>',
#   '<start> 4 दुईवटा कुकुर घाँसमा दौडिरहेका छन्। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/2733659177_d74a00995b.jpg': ['<start> 0 एउटा गोरो बच्चा हरियो खेतमा रूखको हाँगामा सुतिरहेको छ। <end>',
#   '<start> 1 पहेँलो शर्ट र नीलो प्यान्ट लगाएको गोरो कपाल भएको केटा बाहिर घाँसे मैदानमा ठूलो, खसेको रूखको अङ्ग चढिरहेको छ। <end>',
#   '<start> 2 पहेंलो शर्ट र नीलो प्यान्ट लगाएको एक केटा पहाडी क्षेत्रमा रूख चढ्दै छ। <end>',
#   '<start> 3 पहेंलो शर्ट र नीलो प्यान्ट लगाएको एक केटा घाँसे मैदानमा रूखको हाँगामा चढिरहेको छ। <end>',
#   '<start> 4 एक जवान केटा घाँसे पहाडहरूमा रूख चढ्दै। <end>'],
#  '/content/drive/MyDrive/Laptop/Image captioning project/archive/Images/751109943_2a7f8e117f.jpg': ['<start> 0 एउटी केटी सेतो बाल्टिनमा आफ्नो टाउको भिजाउँदै। <end>',
#   '<start> 1 एउटी सानी केटीले आफ्नो कपाल पानीले भरिएको बाल्टिनमा डुबाउँछिन्। <end>',
#   '<start> 2 एउटी सानी केटीले आफ्नो टाउको पानीको कचौरामा डुबेकी छिन्। <end>',
#   '<start> 3 पोशाक लगाएकी एउटी सानी केटीले आफ्नो भिजेको टाउको बाल्टिनबाट उठाउँदै। <end>',
#   '<start> 4 एक जवान केटी सेतो बाल्टीबाट आफ्नो भिजेको कपाल उठाउँदै <end>'],
#  ...}

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from PIL import Image
from tensorflow.keras.layers.experimental import preprocessing
import re
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# Step 1: Tokenization

def tokenize_captions(captions):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(captions)
    return tokenizer

train_captions = [caption for captions in train_data.values() for caption in captions]
tokenizer = tokenize_captions(train_captions)

# %%
# Step 2: Define Preprocessing Functions for Text
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")

strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

VOCAB_SIZE = 10000
seq_length = 20

vectorization = preprocessing.TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=seq_length,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# %%
# Step 3: Image Preprocessing

def preprocess_image(image_path, target_size):
    try:
        image = tf.io.read_file(image_path)
        image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, target_size)
        image = tf.keras.applications.resnet.preprocess_input(image)  # Apply ResNet preprocessing
        return image
    except tf.errors.NotFoundError:
        # Handle missing image file
        print("Image file not found:", image_path)
        return None

def load_image_features(image_caption_mapping, target_size):
    image_features = []
    for image_path in image_caption_mapping.keys():
        image = preprocess_image(image_path, target_size)
        if image is not None:
            image_features.append(image)
    return tf.stack(image_features)


target_image_size = (224, 224)
train_image_features = load_image_features(train_data, target_image_size)
valid_image_features = load_image_features(valid_data, target_image_size)

# %%
def extract_patches(images, patch_size, stride):
    patches = tf.image.extract_patches(
        images=images,
        sizes=[1, patch_size, patch_size, 1],
        strides=[1, stride, stride, 1],
        rates=[1, 1, 1, 1],
        padding='VALID'
    )
    return patches

def preprocess_patches(patches, target_size):
    patches = tf.reshape(patches, shape=[-1, target_size, target_size, patches.shape[-1]])
    patches = tf.image.resize(patches, size=(target_size, target_size))
    return patches

def compute_patch_embeddings(patches, embedding_dim):
    model = keras.applications.ResNet50(include_top=False, weights='imagenet')
    features = model(patches)
    embeddings = layers.Flatten()(features)
    embeddings = layers.Dense(embedding_dim)(embeddings)
    return embeddings

def add_positional_embedding(embeddings, num_patches):
    position_embeddings = layers.Embedding(input_dim=num_patches, output_dim=embedding_dim)(tf.range(num_patches))
    embeddings_with_position = embeddings + position_embeddings
    return embeddings_with_position

# Step 1: Image Preprocessing
patch_size = 16
stride = 4
target_size = 224
embedding_dim = 256

image_patches = extract_patches(train_image_features, patch_size, stride)
preprocessed_patches = preprocess_patches(image_patches, target_size)
patch_embeddings = compute_patch_embeddings(preprocessed_patches, embedding_dim)
image_embeddings = add_positional_embedding(patch_embeddings, preprocessed_patches.shape[0])

# %%
# Step 2: Text Preprocessing

def perform_word_embedding(text_data, vocab_size, embedding_dim):
    vectorization = preprocessing.TextVectorization(
        max_tokens=vocab_size,
        output_mode='int',
        output_sequence_length=seq_length,
        standardize=custom_standardization
    )
    vectorization.adapt(text_data)

    model = keras.Sequential([
        layers.Embedding(vocab_size, embedding_dim),
        # Add more layers as needed
    ])
    embeddings = model(vectorization(text_data))
    return embeddings

# Step 2: Text Preprocessing
vocab_size = 10000
seq_length = 20
embedding_dim = 256

text_embeddings = perform_word_embedding(text_data, vocab_size, embedding_dim)

# %% [markdown]
# ---
#
#
#
# ---

# %%
# Step 1: Image Preprocessing

# Define the Transformer Encoder
class ImageTransformerEncoder(layers.Layer):
    def __init__(self, num_patches, embedding_dim, num_heads, ff_dim, dropout_rate=0.1):
        super(ImageTransformerEncoder, self).__init__()
        self.embedding_dim = embedding_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.dropout_rate = dropout_rate

        self.positional_embedding = layers.Embedding(input_dim=num_patches, output_dim=embedding_dim)
        self.patch_embedding = layers.Dense(embedding_dim)
        self.dropout = layers.Dropout(dropout_rate)
        self.attention = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim)
        self.add_norm_1 = layers.AddNormalization()
        self.feed_forward = keras.Sequential([
            layers.Dense(ff_dim, activation="relu"),
            layers.Dense(embedding_dim),
        ])
        self.add_norm_2 = layers.AddNormalization()

    def call(self, patch_embeddings):
        positions = tf.range(patch_embeddings.shape[1])
        positional_embeddings = self.positional_embedding(positions)
        embeddings = self.patch_embedding(patch_embeddings) + positional_embeddings
        embeddings = self.dropout(embeddings)

        self_attention = self.attention(embeddings, embeddings)
        embeddings = self.add_norm_1(embeddings, self_attention)
        ff_output = self.feed_forward(embeddings)
        encoded_embeddings = self.add_norm_2(embeddings, ff_output)

        return encoded_embeddings

# Define the Transformer Decoder
class TextTransformerDecoder(layers.Layer):
    def __init__(self, vocab_size, embedding_dim, num_heads, ff_dim, seq_length, dropout_rate=0.1):
        super(TextTransformerDecoder, self).__init__()
        self.embedding_dim = embedding_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.seq_length = seq_length
        self.dropout_rate = dropout_rate

        self.positional_embedding = layers.Embedding(input_dim=seq_length, output_dim=embedding_dim)
        self.word_embedding = layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
        self.dropout = layers.Dropout(dropout_rate)
        self.attention_1 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim)
        self.add_norm_1 = layers.AddNormalization()
        self.attention_2 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim)
        self.add_norm_2 = layers.AddNormalization()
        self.feed_forward = keras.Sequential([
            layers.Dense(ff_dim, activation="relu"),
            layers.Dense(embedding_dim),
        ])
        self.add_norm_3 = layers.AddNormalization()
        self.linear = layers.Dense(vocab_size)

    def call(self, encoded_embeddings, text_embeddings):
        positions = tf.range(text_embeddings.shape[1])
        positional_embeddings = self.positional_embedding(positions)
        embeddings = self.word_embedding(text_embeddings) + positional_embeddings
        embeddings = self.dropout(embeddings)

        self_attention = self.attention_1(embeddings, embeddings)
        embeddings = self.add_norm_1(embeddings, self_attention)

        cross_attention = self.attention_2(embeddings, encoded_embeddings)
        embeddings = self.add_norm_2(embeddings, cross_attention)

        ff_output = self.feed_forward(embeddings)
        output_embeddings = self.add_norm_3(embeddings, ff_output)

        logits = self.linear(output_embeddings)

        return logits

# Step 1: Image Preprocessing
patch_size = 16
stride = 4
target_size = 224
embedding_dim = 256

image_patches = extract_patches(train_image_features, patch_size, stride)
preprocessed_patches = preprocess_patches(image_patches, target_size)
patch_embeddings = compute_patch_embeddings(preprocessed_patches, embedding_dim)
image_embeddings = add_positional_embedding(patch_embeddings, preprocessed_patches.shape[0])

# Step 2: Text Preprocessing
vocab_size = 10000
seq_length = 20
embedding_dim = 256

text_embeddings = perform_word_embedding(text_data, vocab_size, embedding_dim)

# Step 3: Define the Transformer Encoder and Decoder
num_patches = preprocessed_patches.shape[1]
num_heads = 8
ff_dim = 512
dropout_rate = 0.1

image_encoder = ImageTransformerEncoder(num_patches, embedding_dim, num_heads, ff_dim, dropout_rate)
text_decoder = TextTransformerDecoder(vocab_size, embedding_dim, num_heads, ff_dim, seq_length, dropout_rate)

# Step 4: Encode Images and Decode Text
encoded_image_embeddings = image_encoder(image_embeddings)
decoded_logits = text_decoder(encoded_image_embeddings, text_embeddings)

# %% [markdown]
# ---
#
#
#
# ---

# %%
# Step 5: Define Loss Function and Metrics
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam()
accuracy_metric = tf.keras.metrics.SparseCategoricalAccuracy()

# Step 6: Define the Training Step
@tf.function
def train_step(image_embeddings, text_embeddings, captions):
    with tf.GradientTape() as tape:
        encoded_image_embeddings = image_encoder(image_embeddings, training=True)
        logits = text_decoder(encoded_image_embeddings, text_embeddings, training=True)
        loss_value = loss_object(captions, logits)

    gradients = tape.gradient(loss_value, image_encoder.trainable_variables + text_decoder.trainable_variables)
    optimizer.apply_gradients(zip(gradients, image_encoder.trainable_variables + text_decoder.trainable_variables))

    accuracy_metric(captions, logits)

    return loss_value

# Step 7: Training Loop
num_epochs = 10

for epoch in range(num_epochs):
    epoch_loss = 0.0
    accuracy_metric.reset_states()

    for batch, (image_embeddings, text_embeddings, captions) in enumerate(train_features):
        loss = train_step(image_embeddings, text_embeddings, captions)
        epoch_loss += loss

        if batch % 100 == 0:
            print(f"Epoch {epoch + 1} Batch {batch} Loss {loss.numpy():.4f} Accuracy {accuracy_metric.result().numpy():.4f}")

    print(f"Epoch {epoch + 1} Loss {epoch_loss / (batch + 1):.4f} Accuracy {accuracy_metric.result().numpy():.4f}")

# Step 8: Evaluation
def evaluate(image_embeddings, text_embeddings):
    encoded_image_embeddings = image_encoder(image_embeddings, training=False)
    logits = text_decoder(encoded_image_embeddings, text_embeddings, training=False)
    predicted_captions = tf.argmax(logits, axis=2)
    return predicted_captions

predicted_captions = evaluate(valid_image_features, valid_captions)

# Step 9: Generate Captions
def generate_captions(image_paths):
    image_features = load_image_features(image_paths, target_image_size)
    encoded_image_embeddings = image_encoder(image_features, training=False)
    text_embeddings = perform_word_embedding(["<start>"] * len(image_paths), vocab_size, embedding_dim)
    captions = []

    for _ in range(max_caption_length):
        logits = text_decoder(encoded_image_embeddings, text_embeddings, training=False)
        predicted_word_ids = tf.argmax(logits, axis=2)
        predicted_words = tokenizer.sequences_to_texts(predicted_word_ids.numpy())
        captions.extend(predicted_words)

        text_embeddings = perform_word_embedding(predicted_words, vocab_size, embedding_dim)

    return captions

image_paths = ["image1.jpg", "image2.jpg", "image3.jpg"]
generated_captions = generate_captions(image_paths)

# Step 10: Save the Model
image_encoder.save("image_encoder.h5")
text_decoder.save("text_decoder.h5")
